# %% [markdown]
# # 5 · Run All Scenarios (sweep) on FABRIC
#
# Execute **every** scenario in `validation/scenarios/` end-to-end on the slice — single
# scenarios plus the expanded `sweep_distance` (6 pts) and `sweep_attenuation` (9 pts) — and
# for each point run the full 4-way cross-validation (QFabric measured + QFabric-sim +
# SeQUeNCe + NetSquid). Then plot QBER and secure key rate vs distance/attenuation.
#
# > ⏳ **This is the long one.** ~18 points × (switch reconfigure + BB84 + 3 simulator runs)
# > ≈ 30–60+ min of slice time. Results are written to `results/all_scenarios.json` after
# > **every** point, so an interruption keeps what's done.
#
# **Prerequisite:** `01_setup_slice` (slice up, data-plane IPs) completed. The simulator
# envs are built in Step 1 below (one-time).

# %% [markdown]
# ### At a glance
# - **Purpose:** batch-run **every** scenario in `validation/scenarios/` (singles + expanded sweeps) and produce the QBER/key-rate-vs-distance/attenuation figures.
# - **Inputs:** `SLICE_NAME`, NetSquid creds (Step 1).
# - **Outputs:** `results/all_scenarios.json` (rewritten after every point) + sweep figures + an all-points table.
# - **Runs on / runtime:** FABRIC JupyterHub; **~30–60+ min** (18 points × switch reconfigure + BB84 + 3 simulator runs). Set `cross_validate=False` for a faster BB84-only sweep.
# - **If something fails:** the sweep is resumable (partial `all_scenarios.json` is kept) and one bad point won't abort the rest; high-loss points may legitimately show the measured backend as SKIPPED while the simulators still populate the row.

# %% [markdown]
# ## Configuration (match notebook 1)

# %%
SLICE_NAME = 'qfabric-bb84-2'

# %%
import os, sys, json
from pathlib import Path

PROJECT_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_DIR)); sys.path.insert(0, str(PROJECT_DIR / 'scripts'))
import deploy_fabric as df

fablib = df.get_fablib()
slice_obj = fablib.get_slice(name=SLICE_NAME)
slice_obj.show()
# Out:
# <style type="text/css">
# #T_f8e58 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_f8e58 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f8e58 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_f8e58_row0_col0, #T_f8e58_row0_col1, #T_f8e58_row1_col0, #T_f8e58_row1_col1, #T_f8e58_row2_col0, #T_f8e58_row2_col1, #T_f8e58_row3_col0, #T_f8e58_row3_col1, #T_f8e58_row4_col0, #T_f8e58_row4_col1, #T_f8e58_row5_col0, #T_f8e58_row5_col1, #T_f8e58_row6_col0, #T_f8e58_row6_col1, #T_f8e58_row7_col0, #T_f8e58_row7_col1, #T_f8e58_row8_col0, #T_f8e58_row8_col1, #T_f8e58_row9_col0, #T_f8e58_row9_col1, #T_f8e58_row10_col0, #T_f8e58_row10_col1, #T_f8e58_row11_col0, #T_f8e58_row11_col1, #T_f8e58_row12_col0, #T_f8e58_row12_col1, #T_f8e58_row13_col0, #T_f8e58_row13_col1, #T_f8e58_row14_col0, #T_f8e58_row14_col1, #T_f8e58_row15_col0, #T_f8e58_row15_col1, #T_f8e58_row16_col0, #T_f8e58_row16_col1, #T_f8e58_row17_col0, #T_f8e58_row17_col1, #T_f8e58_row18_col0, #T_f8e58_row18_col1, #T_f8e58_row19_col0, #T_f8e58_row19_col1, #T_f8e58_row20_col0, #T_f8e58_row20_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_f8e58">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f8e58_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_f8e58_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_f8e58_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_f8e58_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_f8e58_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row4_col0" class="data row4 col0" >CEPH Manager</td>
#       <td id="T_f8e58_row4_col1" class="data row4 col1" >https://ceph-mgr.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row5_col0" class="data row5 col0" >Token File</td>
#       <td id="T_f8e58_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/id_token.json</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row6_col0" class="data row6 col0" >Project ID</td>
#       <td id="T_f8e58_row6_col1" class="data row6 col1" >24f4c8f3-e872-492a-9a83-b48211a91966</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row7_col0" class="data row7 col0" >Bastion Host</td>
#       <td id="T_f8e58_row7_col1" class="data row7 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row8_col0" class="data row8 col0" >Bastion Username</td>
#       <td id="T_f8e58_row8_col1" class="data row8 col1" >audreyf_0000527467</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row9_col0" class="data row9 col0" >Bastion Private Key File</td>
#       <td id="T_f8e58_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row10_col0" class="data row10 col0" >Slice Public Key File</td>
#       <td id="T_f8e58_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row11_col0" class="data row11 col0" >Slice Private Key File</td>
#       <td id="T_f8e58_row11_col1" class="data row11 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row12_col0" class="data row12 col0" >Sites to avoid</td>
#       <td id="T_f8e58_row12_col1" class="data row12 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row13_col0" class="data row13 col0" >SSH Command Line</td>
#       <td id="T_f8e58_row13_col1" class="data row13 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row14_col0" class="data row14 col0" >Log Level</td>
#       <td id="T_f8e58_row14_col1" class="data row14 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row15_col0" class="data row15 col0" >Log File</td>
#       <td id="T_f8e58_row15_col1" class="data row15 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row16_col0" class="data row16 col0" >Log Propagate</td>
#       <td id="T_f8e58_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row17_col0" class="data row17 col0" >Bastion SSH Config File</td>
#       <td id="T_f8e58_row17_col1" class="data row17 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row18_col0" class="data row18 col0" >Fabric Meta Data Release Tag</td>
#       <td id="T_f8e58_row18_col1" class="data row18 col1" >main</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row19_col0" class="data row19 col0" >Version</td>
#       <td id="T_f8e58_row19_col1" class="data row19 col1" >2.0.6</td>
#     </tr>
#     <tr>
#       <td id="T_f8e58_row20_col0" class="data row20 col0" >Data directory</td>
#       <td id="T_f8e58_row20_col1" class="data row20 col1" >/tmp/fablib</td>
#     </tr>
#   </tbody>
# </table>
# User: audreyf@illinois.edu bastion key is valid!
# Configuration is valid
# <style type="text/css">
# #T_6e970 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_6e970 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6e970 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_6e970_row0_col0, #T_6e970_row0_col1, #T_6e970_row1_col0, #T_6e970_row1_col1, #T_6e970_row2_col0, #T_6e970_row2_col1, #T_6e970_row3_col0, #T_6e970_row3_col1, #T_6e970_row4_col0, #T_6e970_row4_col1, #T_6e970_row5_col0, #T_6e970_row5_col1, #T_6e970_row6_col0, #T_6e970_row6_col1, #T_6e970_row7_col0, #T_6e970_row7_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_6e970">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6e970_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_6e970_row0_col1" class="data row0 col1" >d1035024-ba8f-4203-b038-632073474a82</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_6e970_row1_col1" class="data row1 col1" >qfabric-bb84-2</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_6e970_row2_col1" class="data row2 col1" >2026-07-09 04:09:19 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_6e970_row3_col1" class="data row3 col1" >2026-07-07 16:08:19 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_6e970_row4_col1" class="data row4 col1" >24f4c8f3-e872-492a-9a83-b48211a91966</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_6e970_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row6_col0" class="data row6 col0" >Email</td>
#       <td id="T_6e970_row6_col1" class="data row6 col1" >audreyf@illinois.edu</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row7_col0" class="data row7 col0" >UserId</td>
#       <td id="T_6e970_row7_col1" class="data row7 col1" >8616dd8c-5b61-45db-84bb-791c21e82a89</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6e970 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_6e970 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6e970 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_6e970_row0_col0, #T_6e970_row0_col1, #T_6e970_row1_col0, #T_6e970_row1_col1, #T_6e970_row2_col0, #T_6e970_row2_col1, #T_6e970_row3_col0, #T_6e970_row3_col1, #T_6e970_row4_col0, #T_6e970_row4_col1, #T_6e970_row5_col0, #T_6e970_row5_col1, #T_6e970_row6_col0, #T_6e970_row6_col1, #T_6e970_row7_col0, #T_6e970_row7_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_6e970">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6e970_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_6e970_row0_col1" class="data row0 col1" >d1035024-ba8f-4203-b038-632073474a82</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_6e970_row1_col1" class="data row1 col1" >qfabric-bb84-2</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_6e970_row2_col1" class="data row2 col1" >2026-07-09 04:09:19 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_6e970_row3_col1" class="data row3 col1" >2026-07-07 16:08:19 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_6e970_row4_col1" class="data row4 col1" >24f4c8f3-e872-492a-9a83-b48211a91966</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_6e970_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row6_col0" class="data row6 col0" >Email</td>
#       <td id="T_6e970_row6_col1" class="data row6 col1" >audreyf@illinois.edu</td>
#     </tr>
#     <tr>
#       <td id="T_6e970_row7_col0" class="data row7 col0" >UserId</td>
#       <td id="T_6e970_row7_col1" class="data row7 col1" >8616dd8c-5b61-45db-84bb-791c21e82a89</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 1 — Build simulator envs on the nodes (one-time)
# Set your netsquid.org credentials first so NetSquid installs on the bob node.

# %%
# os.environ['NETSQUID_USER'] = '...'
# os.environ['NETSQUID_PASS'] = '...'
df.setup_sim_envs(slice_obj)
# Out:
# === Setting up simulator envs on FABRIC nodes (one-time, several min) ===
#   [switch] QFabric-sim (.venv-qsim)...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# python3-pip is already the newest version (22.0.2+dfsg-1ubuntu0.7).
# python3-venv is already the newest version (3.10.6-1~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
#   [alice] SeQUeNCe 1.0 on Python 3.12 (.venv-seq)...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# software-properties-common is already the newest version (0.99.22.9).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://nova.clouds.archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 http://nova.clouds.archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Reading package lists...
# Repository: 'deb https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu/ jammy main'
# Description:
# This PPA contains more recent Python versions packaged for Ubuntu.
#
# Disclaimer: there's no guarantee of timely updates in case of security problems or other issues. If you want to use them in a security-or-otherwise-critical environment (say, on a production server), you do so at your own risk.
#
# Update Note
# ===========
# Please use this repository instead of ppa:fkrull/deadsnakes.
#
# Reporting Issues
# ================
#
# Issues can be reported in the master issue tracker at:
# https://github.com/deadsnakes/issues/issues
#
# Supported Ubuntu and Python Versions
# ====================================
#
# - Ubuntu 22.04 (jammy) Python3.7+ (NOT Python3.10)
# - Ubuntu 24.04 (noble) Python3.7+ (NOT Python3.12)
# - Ubuntu 26.04 (resolute) Python3.7+ (NOT Python3.14)
# - Note: Python 3.10 (jammy), Python3.12 (noble), Python3.14 (resolute) are not provided by deadsnakes as upstream ubuntu provides those packages.
#
# Why some packages aren't built:
# - Note: for 22.04+, older python versions requre libssl<3 so they are not currently built
# - If you need these, reach out to asottile to set up a private ppa
#
# The packages may also work on other versions of Ubuntu or Debian, but that is not tested or supported.
#
# Packages
# ========
#
# The packages provided here are loosely based on the debian upstream packages with some modifications to make them more usable as non-default pythons and on ubuntu.  As such, the packages follow debian's patterns and often do not include a full python distribution with just `apt install python#.#`.  Here is a list of packages that may be useful along with the default install:
#
# - `python#.#-dev`: includes development headers for building C extensions
# - `python#.#-venv`: provides the standard library `venv` module
# - `python#.#-distutils`: provides the standard library `distutils` module
# - `python#.#-lib2to3`: provides the `2to3-#.#` utility as well as the standard library `lib2to3` module
# - `python#.#-gdbm`: provides the standard library `dbm.gnu` module
# - `python#.#-tk`: provides the standard library `tkinter` module
#
# Third-Party Python Modules
# ==========================
#
# Python modules in the official Ubuntu repositories are packaged to work with the Python interpreters from the official repositories. Accordingly, they generally won't work with the Python interpreters from this PPA. As an exception, pure-Python modules for Python 3 will work, but any compiled extension modules won't.
#
# To install 3rd-party Python modules, you should use the common Python packaging tools.  For an introduction into the Python packaging ecosystem and its tools, refer to the Python Packaging User Guide:
# https://packaging.python.org/installing/
#
# Sources
# =======
# The package sources are available at:
# https://github.com/deadsnakes/
#
# Nightly Builds
# ==============
#
# For nightly builds, see ppa:deadsnakes/nightly https://launchpad.net/~deadsnakes/+archive/ubuntu/nightly
# More info: https://launchpad.net/~deadsnakes/+archive/ubuntu/ppa
# Adding repository.
# Found existing deb entry in /etc/apt/sources.list.d/deadsnakes-ubuntu-ppa-jammy.list
# Adding deb entry to /etc/apt/sources.list.d/deadsnakes-ubuntu-ppa-jammy.list
# Found existing deb-src entry in /etc/apt/sources.list.d/deadsnakes-ubuntu-ppa-jammy.list
# Adding disabled deb-src entry to /etc/apt/sources.list.d/deadsnakes-ubuntu-ppa-jammy.list
# Adding key to /etc/apt/trusted.gpg.d/deadsnakes-ubuntu-ppa.gpg with fingerprint F23C5A6CF475977595C89F51BA6932366A755776
# Reading package lists...
# Building dependency tree...
# Reading state information...
# python3.12 is already the newest version (3.12.13-1+jammy1).
# python3.12-venv is already the newest version (3.12.13-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
#   [bob] NetSquid (.venv-nsq)...
#     WARNING: NETSQUID_USER/NETSQUID_PASS not set — NetSquid will not install.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# python3-pip is already the newest version (22.0.2+dfsg-1ubuntu0.7).
# python3-venv is already the newest version (3.10.6-1~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# ERROR: Could not find a version that satisfies the requirement netsquid (from versions: none)
# ERROR: No matching distribution found for netsquid
#   Simulator envs ready (alice=SeQUeNCe, bob=NetSquid, switch=QFabric-sim)

# %% [markdown]
# ## Step 2 — Run every scenario (this takes a while)
# Reconfigures the switch loss threshold per point, runs BB84, then the 4-way comparison.
# Set `cross_validate=False` for a faster BB84-only sweep.

# %%
rows = df.run_all_scenarios_on_fabric(slice_obj, cross_validate=True)
print(f'\nCompleted {len(rows)} scenario points.')
# Out:
# Discovered scenarios in validation/scenarios -> 38 runs
#
# ##### [1/38] baseline_1km : baseline_1km (dist=1.0 km, atten=0.2 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38243
#   QBER:            0.0084
#   Secure key rate: 0.2962
#   Final key bits:  29616
#   Elapsed:         113.83s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95492 photons
# Bob: 95492 photons arrived, 76297 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76297
#   Sifted bits:            38243
#   QBER:                   0.0084
#   Secure key rate:        0.2962
#   Final key bits:         29616
#   Elapsed:                123.82s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76297
#   sifted_bits: 38243
#   qber: 0.008368200836820083
#   secure_key_rate: 0.29616
#   final_key_bits: 29616
#   elapsed_seconds: 123.82486271858215
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0084, sifted=38243
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [2/38] fabric_1km : fabric_1km (dist=1.0 km, atten=0.2 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3846
#   QBER:            0.0026
#   Secure key rate: 0.3281
#   Final key bits:  3281
#   Elapsed:         42.11s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9571 photons
# Bob: 9571 photons arrived, 7676 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7676
#   Sifted bits:            3846
#   QBER:                   0.0026
#   Secure key rate:        0.3281
#   Final key bits:         3281
#   Elapsed:                52.11s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7676
#   sifted_bits: 3846
#   qber: 0.0026041666666666665
#   secure_key_rate: 0.3281
#   final_key_bits: 3281
#   elapsed_seconds: 52.11396622657776
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0026, sifted=3846
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [3/38] quick_test : quick_test (dist=1.0 km, atten=0.2 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3818
#   QBER:            0.0131
#   Secure key rate: 0.2743
#   Final key bits:  2743
#   Elapsed:         42.20s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9575 photons
# Bob: 9575 photons arrived, 7656 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7656
#   Sifted bits:            3818
#   QBER:                   0.0131
#   Secure key rate:        0.2743
#   Final key bits:         2743
#   Elapsed:                52.20s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7656
#   sifted_bits: 3818
#   qber: 0.013123359580052493
#   secure_key_rate: 0.2743
#   final_key_bits: 2743
#   elapsed_seconds: 52.20171093940735
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0131, sifted=3818
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [4/38] sweep_attenuation : attenuation_db_per_km=0.1 (dist=10.0 km, atten=0.1 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=883353505) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38167
#   QBER:            0.0121
#   Secure key rate: 0.2788
#   Final key bits:  27884
#   Elapsed:         117.08s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95522 photons
# Bob: 95522 photons arrived, 76444 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76444
#   Sifted bits:            38167
#   QBER:                   0.0121
#   Secure key rate:        0.2788
#   Final key bits:         27884
#   Elapsed:                127.07s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76444
#   sifted_bits: 38167
#   qber: 0.012054507337526206
#   secure_key_rate: 0.27884
#   final_key_bits: 27884
#   elapsed_seconds: 127.07457065582275
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0121, sifted=38167
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [5/38] sweep_attenuation : attenuation_db_per_km=0.15 (dist=10.0 km, atten=0.15 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=1254363304) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     37913
#   QBER:            0.0116
#   Secure key rate: 0.2789
#   Final key bits:  27893
#   Elapsed:         114.02s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95452 photons
# Bob: 95452 photons arrived, 76314 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76314
#   Sifted bits:            37913
#   QBER:                   0.0116
#   Secure key rate:        0.2789
#   Final key bits:         27893
#   Elapsed:                124.02s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76314
#   sifted_bits: 37913
#   qber: 0.01160643629649169
#   secure_key_rate: 0.27893
#   final_key_bits: 27893
#   elapsed_seconds: 124.02291822433472
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0116, sifted=37913
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [6/38] sweep_attenuation : attenuation_db_per_km=0.2 (dist=10.0 km, atten=0.2 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=1585026136) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     37913
#   QBER:            0.0132
#   Secure key rate: 0.2721
#   Final key bits:  27211
#   Elapsed:         118.16s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95371 photons
# Bob: 95371 photons arrived, 76248 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76248
#   Sifted bits:            37913
#   QBER:                   0.0132
#   Secure key rate:        0.2721
#   Final key bits:         27211
#   Elapsed:                128.17s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76248
#   sifted_bits: 37913
#   qber: 0.013189132155104194
#   secure_key_rate: 0.27211
#   final_key_bits: 27211
#   elapsed_seconds: 128.1668405532837
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0132, sifted=37913
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [7/38] sweep_attenuation : attenuation_db_per_km=0.25 (dist=10.0 km, atten=0.25 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=1879729695) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38021
#   QBER:            0.0087
#   Secure key rate: 0.2930
#   Final key bits:  29297
#   Elapsed:         118.71s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95493 photons
# Bob: 95493 photons arrived, 76443 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76443
#   Sifted bits:            38021
#   QBER:                   0.0087
#   Secure key rate:        0.2930
#   Final key bits:         29297
#   Elapsed:                128.71s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76443
#   sifted_bits: 38021
#   qber: 0.008679642293529721
#   secure_key_rate: 0.29297
#   final_key_bits: 29297
#   elapsed_seconds: 128.70919132232666
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0087, sifted=38021
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [8/38] sweep_attenuation : attenuation_db_per_km=0.3 (dist=10.0 km, atten=0.3 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=2142384518) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38343
#   QBER:            0.0094
#   Secure key rate: 0.2921
#   Final key bits:  29213
#   Elapsed:         113.20s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95476 photons
# Bob: 95476 photons arrived, 76317 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76317
#   Sifted bits:            38343
#   QBER:                   0.0094
#   Secure key rate:        0.2921
#   Final key bits:         29213
#   Elapsed:                123.20s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76317
#   sifted_bits: 38343
#   qber: 0.009389671361502348
#   secure_key_rate: 0.29213
#   final_key_bits: 29213
#   elapsed_seconds: 123.19982171058655
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0094, sifted=38343
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [9/38] sweep_attenuation : attenuation_db_per_km=0.35 (dist=10.0 km, atten=0.35 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=2376475876) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38416
#   QBER:            0.0091
#   Secure key rate: 0.2940
#   Final key bits:  29399
#   Elapsed:         112.83s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95451 photons
# Bob: 95451 photons arrived, 76349 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76349
#   Sifted bits:            38416
#   QBER:                   0.0091
#   Secure key rate:        0.2940
#   Final key bits:         29399
#   Elapsed:                122.84s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76349
#   sifted_bits: 38416
#   qber: 0.009112210361884926
#   secure_key_rate: 0.29399
#   final_key_bits: 29399
#   elapsed_seconds: 122.83635926246643
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0091, sifted=38416
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [10/38] sweep_attenuation : attenuation_db_per_km=0.4 (dist=10.0 km, atten=0.4 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=2585110018) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38375
#   QBER:            0.0115
#   Secure key rate: 0.2829
#   Final key bits:  28295
#   Elapsed:         118.02s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95615 photons
# Bob: 95615 photons arrived, 76495 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76495
#   Sifted bits:            38375
#   QBER:                   0.0115
#   Secure key rate:        0.2829
#   Final key bits:         28295
#   Elapsed:                128.06s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76495
#   sifted_bits: 38375
#   qber: 0.011467292155329685
#   secure_key_rate: 0.28295
#   final_key_bits: 28295
#   elapsed_seconds: 128.05667066574097
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0115, sifted=38375
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [11/38] sweep_attenuation : attenuation_db_per_km=0.45 (dist=10.0 km, atten=0.45 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=2771055393) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38108
#   QBER:            0.0087
#   Secure key rate: 0.2937
#   Final key bits:  29374
#   Elapsed:         110.74s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95500 photons
# Bob: 95500 photons arrived, 76425 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76425
#   Sifted bits:            38108
#   QBER:                   0.0087
#   Secure key rate:        0.2937
#   Final key bits:         29374
#   Elapsed:                120.73s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76425
#   sifted_bits: 38108
#   qber: 0.008661417322834646
#   secure_key_rate: 0.29374
#   final_key_bits: 29374
#   elapsed_seconds: 120.73239088058472
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0087, sifted=38108
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [12/38] sweep_attenuation : attenuation_db_per_km=0.5 (dist=10.0 km, atten=0.5 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=2936779382) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38117
#   QBER:            0.0073
#   Secure key rate: 0.3001
#   Final key bits:  30008
#   Elapsed:         107.99s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95495 photons
# Bob: 95495 photons arrived, 76451 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76451
#   Sifted bits:            38117
#   QBER:                   0.0073
#   Secure key rate:        0.3001
#   Final key bits:         30008
#   Elapsed:                117.97s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76451
#   sifted_bits: 38117
#   qber: 0.007347152978220939
#   secure_key_rate: 0.30008
#   final_key_bits: 30008
#   elapsed_seconds: 117.97072315216064
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0073, sifted=38117
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [13/38] sweep_dark_count : dark_count_rate_hz=100 (dist=10.0 km, atten=0.2 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=1585026136) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38166
#   QBER:            0.0107
#   Secure key rate: 0.2846
#   Final key bits:  28463
#   Elapsed:         116.10s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95564 photons
# Bob: 95564 photons arrived, 76515 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76515
#   Sifted bits:            38166
#   QBER:                   0.0107
#   Secure key rate:        0.2846
#   Final key bits:         28463
#   Elapsed:                126.09s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76515
#   sifted_bits: 38166
#   qber: 0.010744234800838574
#   secure_key_rate: 0.28463
#   final_key_bits: 28463
#   elapsed_seconds: 126.08875489234924
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0107, sifted=38166
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [14/38] sweep_dark_count : dark_count_rate_hz=1000 (dist=10.0 km, atten=0.2 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=1585026136) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38107
#   QBER:            0.0084
#   Secure key rate: 0.2950
#   Final key bits:  29496
#   Elapsed:         110.46s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95565 photons
# Bob: 95565 photons arrived, 76343 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76343
#   Sifted bits:            38107
#   QBER:                   0.0084
#   Secure key rate:        0.2950
#   Final key bits:         29496
#   Elapsed:                120.47s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76343
#   sifted_bits: 38107
#   qber: 0.008398950131233596
#   secure_key_rate: 0.29496
#   final_key_bits: 29496
#   elapsed_seconds: 120.47262859344482
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0084, sifted=38107
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [15/38] sweep_dark_count : dark_count_rate_hz=5000 (dist=10.0 km, atten=0.2 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=1585026136) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38119
#   QBER:            0.0073
#   Secure key rate: 0.3001
#   Final key bits:  30009
#   Elapsed:         115.10s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95572 photons
# Bob: 95572 photons arrived, 76508 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76508
#   Sifted bits:            38119
#   QBER:                   0.0073
#   Secure key rate:        0.3001
#   Final key bits:         30009
#   Elapsed:                125.07s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76508
#   sifted_bits: 38119
#   qber: 0.007347152978220939
#   secure_key_rate: 0.30009
#   final_key_bits: 30009
#   elapsed_seconds: 125.07366561889648
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0073, sifted=38119
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [16/38] sweep_dark_count : dark_count_rate_hz=19306 (dist=10.0 km, atten=0.2 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=1585026136) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
# ...
#   elapsed_seconds: 125.79243230819702
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.1009, sifted=38150
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [34/38] sweep_polarization : polarization_fidelity=0.85 (dist=10.0 km, atten=0.2 dB/km, F=0.85) #####
#
# === Configuring switch (threshold=1585026136) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38219
#   QBER:            0.0759
#   Secure key rate: 0.0774
#   Final key bits:  7735
#   Elapsed:         109.00s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95427 photons
# Bob: 95427 photons arrived, 76331 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76331
#   Sifted bits:            38219
#   QBER:                   0.0759
#   Secure key rate:        0.0774
#   Final key bits:         7735
#   Elapsed:                119.00s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76331
#   sifted_bits: 38219
#   qber: 0.07589636220884585
#   secure_key_rate: 0.07735
#   final_key_bits: 7735
#   elapsed_seconds: 118.99577283859253
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0759, sifted=38219
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [35/38] sweep_polarization : polarization_fidelity=0.9 (dist=10.0 km, atten=0.2 dB/km, F=0.9) #####
#
# === Configuring switch (threshold=1585026136) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38240
#   QBER:            0.0557
#   Secure key rate: 0.1307
#   Final key bits:  13068
#   Elapsed:         115.27s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95520 photons
# Bob: 95520 photons arrived, 76519 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76519
#   Sifted bits:            38240
#   QBER:                   0.0557
#   Secure key rate:        0.1307
#   Final key bits:         13068
#   Elapsed:                125.27s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76519
#   sifted_bits: 38240
#   qber: 0.055700836820083685
#   secure_key_rate: 0.13068
#   final_key_bits: 13068
#   elapsed_seconds: 125.26695537567139
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0557, sifted=38240
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [36/38] sweep_polarization : polarization_fidelity=0.95 (dist=10.0 km, atten=0.2 dB/km, F=0.95) #####
#
# === Configuring switch (threshold=1585026136) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38247
#   QBER:            0.0254
#   Secure key rate: 0.2268
#   Final key bits:  22678
#   Elapsed:         112.10s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95385 photons
# Bob: 95385 photons arrived, 76451 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76451
#   Sifted bits:            38247
#   QBER:                   0.0254
#   Secure key rate:        0.2268
#   Final key bits:         22678
#   Elapsed:                122.14s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76451
#   sifted_bits: 38247
#   qber: 0.02536610878661088
#   secure_key_rate: 0.22678
#   final_key_bits: 22678
#   elapsed_seconds: 122.13708186149597
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0254, sifted=38247
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [37/38] sweep_polarization : polarization_fidelity=0.98 (dist=10.0 km, atten=0.2 dB/km, F=0.98) #####
#
# === Configuring switch (threshold=1585026136) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38034
#   QBER:            0.0100
#   Secure key rate: 0.2870
#   Final key bits:  28703
#   Elapsed:         115.18s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95441 photons
# Bob: 95441 photons arrived, 76371 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76371
#   Sifted bits:            38034
#   QBER:                   0.0100
#   Secure key rate:        0.2870
#   Final key bits:         28703
#   Elapsed:                125.20s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76371
#   sifted_bits: 38034
#   qber: 0.009992111490928214
#   secure_key_rate: 0.28703
#   final_key_bits: 28703
#   elapsed_seconds: 125.19888043403625
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0100, sifted=38034
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# ##### [38/38] sweep_polarization : polarization_fidelity=1.0 (dist=10.0 km, atten=0.2 dB/km, F=1.0) #####
#
# === Configuring switch (threshold=1585026136) ===
#   Switch interfaces: enp7s0 (Alice), enp8s0 (Bob)
#   Alice MAC: 2E:C6:67:6F:9F:11
#   Bob MAC:   06:C1:A6:14:84:EA
#   Switch Alice-side MAC: 32:CA:F2:F8:00:90
#   Switch Bob-side MAC:   32:F4:25:17:27:B3
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 100000 photons on enp7s0
# Alice: Finished sending 100000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    100000
#   Sifted bits:     38260
#   QBER:            0.0000
#   Secure key rate: 0.3443
#   Final key bits:  34434
#   Elapsed:         113.75s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 95535 photons
# Bob: 95535 photons arrived, 76543 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 76543
#   Sifted bits:            38260
#   QBER:                   0.0000
#   Secure key rate:        0.3443
#   Final key bits:         34434
#   Elapsed:                123.75s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 100000
#   photons_received: 76543
#   sifted_bits: 38260
#   qber: 0.0
#   secure_key_rate: 0.34434
#   final_key_bits: 34434
#   elapsed_seconds: 123.74856305122375
#
# === Cross-validation on FABRIC nodes ===
#   QFabric (FABRIC measured): QBER=0.0000, sifted=38260
#   QFabric-sim on switch...
#   SeQUeNCe on alice...
#   NetSquid on bob...
#
# Saved all-scenario results -> /home/fabric/work/qfabric/results/all_scenarios.json (38 points)
#
# Completed 38 scenario points.

# %% [markdown]
# ## Step 3 — Sweep figures: QBER & key rate vs distance / attenuation
# One line per backend; loads `results/all_scenarios.json` (so this cell also works on a
# previously-saved sweep without re-running Step 2).

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
rows = json.loads((PROJECT_DIR / 'results' / 'all_scenarios.json').read_text())

def _ok(b):
    return (not b.get('extra', {}).get('error')) and b.get('sifted_bits', 0) > 0

def plot_group(group, xkey, xlabel):
    pts = sorted([r for r in rows if r['group'] == group], key=lambda r: r[xkey])
    if not pts:
        print(f'(no points for {group})'); return
    platforms = []
    for r in pts:
        for b in r['backends']:
            if b['platform'] not in platforms: platforms.append(b['platform'])
    fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))
    for p in platforms:
        xs, q, s = [], [], []
        for r in pts:
            b = next((b for b in r['backends'] if b['platform'] == p and _ok(b)), None)
            if b:
                xs.append(r[xkey]); q.append(b['qber'] * 100); s.append(b.get('secure_key_rate', 0))
        if xs:
            axes[0].plot(xs, q, marker='o', label=p)
            axes[1].plot(xs, s, marker='o', label=p)
    axes[0].set(xlabel=xlabel, ylabel='QBER (%)', title=f'QBER vs {xlabel}')
    axes[1].set(xlabel=xlabel, ylabel='Secure key rate (bits/photon)', title=f'Key rate vs {xlabel}')
    for ax in axes: ax.grid(alpha=0.3); ax.legend()
    fig.suptitle(group); plt.tight_layout(); plt.show()

plot_group('sweep_dark_count', 'dark_count_rate_hz', 'dark count rate (cps)')
plot_group('sweep_efficiency', 'detector_efficiency', 'detector efficiency')
plot_group('sweep_polarization', 'polarization_fidelity', 'polarization fidelity')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 31
#      27     axes[1].set(xlabel=xlabel, ylabel='Secure key rate (bits/photon)', title=f'Key rate vs {xlabel}')
#      28     for ax in axes: ax.grid(alpha=0.3); ax.legend()
#      29     fig.suptitle(group); plt.tight_layout(); plt.show()
#      30
# ---> 31 plot_group('sweep_dark_count', 'dark_count_rate_hz', 'dark count rate (cps)')
#      32 plot_group('sweep_efficiency', 'detector_efficiency', 'detector efficiency')
#      33 plot_group('sweep_polarization', 'polarization_fidelity', 'polarization fidelity')
#
# Cell In[5], line 9, in plot_group(group, xkey, xlabel)
#       8 def plot_group(group, xkey, xlabel):
# ----> 9     pts = sorted([r for r in rows if r['group'] == group], key=lambda r: r[xkey])
#      10     if not pts:
#      11         print(f'(no points for {group})'); return
#      12     platforms = []
#
# Cell In[5], line 9, in plot_group.<locals>.<lambda>(r)
# ----> 9     pts = sorted([r for r in rows if r['group'] == group], key=lambda r: r[xkey])
#
# KeyError: 'dark_count_rate_hz'

# %% [markdown]
# ## Step 4 — All-scenarios summary table
#
# Every point (singles + sweep points) with each backend's QBER. A blank/`NaN`
# means that backend was SKIPPED for that point (e.g. a measured run that produced
# no key at high loss, or an uninstalled simulator).

# %%
import pandas as pd
tbl = []
for r in rows:
    row = {'group': r['group'], 'scenario': r['scenario'],
           'distance_km': r['distance_km'], 'atten': r['attenuation_db_per_km']}
    for b in r['backends']:
        row[b['platform']] = round(b['qber'], 4) if _ok(b) else None
    tbl.append(row)
df = pd.DataFrame(tbl)
print(f'{len(df)} scenario points')
df

# %% [markdown]
# ---
# All scenarios executed. `results/all_scenarios.json` holds every point × backend for
# further analysis or for the paper figures.
