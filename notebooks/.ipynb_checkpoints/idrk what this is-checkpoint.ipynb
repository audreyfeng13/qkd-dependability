# %% [markdown]
# # 6 · Classical-Network Effects on QKD
#
# **The core QFabric contribution.** Pure quantum-network simulators assume an *ideal*
# classical control channel. QFabric runs BB84's classical sifting over the real FABRIC
# link, so we can measure how classical-network conditions affect QKD — something
# SeQUeNCe/NetSquid cannot show.
#
# Key point: because the classical channel is TCP (reliable), latency/jitter/loss do **not**
# change QBER or bits-per-photon — they change **time-to-key** and effective **key bits/second**.
# This notebook impairs *only* the classical channel (TCP:5100, leaving the photon data plane
# untouched) across a set of conditions and plots the impact.

# %% [markdown]
# ### At a glance
# - **Purpose:** quantify how classical-channel latency/jitter/loss affect BB84 throughput.
# - **Inputs:** `SLICE_NAME`, `SCENARIO`, and a list of network `conditions`.
# - **Outputs:** `results/network_effects.json` + plots (bits/s, time-to-key, QBER per condition).
# - **Runs on / runtime:** FABRIC JupyterHub; ~`len(conditions)` × a BB84 run (a few min each).
# - **If something fails:** a severe condition may time out → that row is recorded as failed; netem is always cleared at the end (and on each iteration).
#
# **Prerequisite:** `01_setup_slice` completed (switch running, data-plane IPs up).

# %% [markdown]
# ## Configuration

# %%
SLICE_NAME = 'qfabric-bb84-2'
SCENARIO   = 'validation/scenarios/fabric_1km.yml'

# %%
import os, sys, json
from pathlib import Path

PROJECT_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_DIR)); sys.path.insert(0, str(PROJECT_DIR / 'scripts'))
import deploy_fabric as df

fablib = df.get_fablib()
slice_obj = fablib.get_slice(name=SLICE_NAME)
slice_obj.show()
# Out:
# <style type="text/css">
# #T_ef43e tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ef43e tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ef43e caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_ef43e_row0_col0, #T_ef43e_row0_col1, #T_ef43e_row1_col0, #T_ef43e_row1_col1, #T_ef43e_row2_col0, #T_ef43e_row2_col1, #T_ef43e_row3_col0, #T_ef43e_row3_col1, #T_ef43e_row4_col0, #T_ef43e_row4_col1, #T_ef43e_row5_col0, #T_ef43e_row5_col1, #T_ef43e_row6_col0, #T_ef43e_row6_col1, #T_ef43e_row7_col0, #T_ef43e_row7_col1, #T_ef43e_row8_col0, #T_ef43e_row8_col1, #T_ef43e_row9_col0, #T_ef43e_row9_col1, #T_ef43e_row10_col0, #T_ef43e_row10_col1, #T_ef43e_row11_col0, #T_ef43e_row11_col1, #T_ef43e_row12_col0, #T_ef43e_row12_col1, #T_ef43e_row13_col0, #T_ef43e_row13_col1, #T_ef43e_row14_col0, #T_ef43e_row14_col1, #T_ef43e_row15_col0, #T_ef43e_row15_col1, #T_ef43e_row16_col0, #T_ef43e_row16_col1, #T_ef43e_row17_col0, #T_ef43e_row17_col1, #T_ef43e_row18_col0, #T_ef43e_row18_col1, #T_ef43e_row19_col0, #T_ef43e_row19_col1, #T_ef43e_row20_col0, #T_ef43e_row20_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_ef43e">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ef43e_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_ef43e_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_ef43e_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_ef43e_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row3_col0" class="data row3 col0" >Token File</td>
#       <td id="T_ef43e_row3_col1" class="data row3 col1" >/home/fabric/work/fabric_config/id_token.json</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_ef43e_row4_col1" class="data row4 col1" >24f4c8f3-e872-492a-9a83-b48211a91966</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row5_col0" class="data row5 col0" >Bastion Host</td>
#       <td id="T_ef43e_row5_col1" class="data row5 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row6_col0" class="data row6 col0" >Bastion Username</td>
#       <td id="T_ef43e_row6_col1" class="data row6 col1" >audreyf_0000527467</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row7_col0" class="data row7 col0" >Bastion Private Key File</td>
#       <td id="T_ef43e_row7_col1" class="data row7 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row8_col0" class="data row8 col0" >Slice Private Key File</td>
#       <td id="T_ef43e_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_ef43e_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row10_col0" class="data row10 col0" >Bastion SSH Config File</td>
#       <td id="T_ef43e_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row11_col0" class="data row11 col0" >Version</td>
#       <td id="T_ef43e_row11_col1" class="data row11 col1" >2.0.6</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_ef43e_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row13_col0" class="data row13 col0" >Log File</td>
#       <td id="T_ef43e_row13_col1" class="data row13 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row14_col0" class="data row14 col0" >Log Propagate</td>
#       <td id="T_ef43e_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row15_col0" class="data row15 col0" >Data directory</td>
#       <td id="T_ef43e_row15_col1" class="data row15 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row16_col0" class="data row16 col0" >Artifact Manager</td>
#       <td id="T_ef43e_row16_col1" class="data row16 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row17_col0" class="data row17 col0" >CEPH Manager</td>
#       <td id="T_ef43e_row17_col1" class="data row17 col1" >https://ceph-mgr.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row18_col0" class="data row18 col0" >Sites to avoid</td>
#       <td id="T_ef43e_row18_col1" class="data row18 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row19_col0" class="data row19 col0" >SSH Command Line</td>
#       <td id="T_ef43e_row19_col1" class="data row19 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_ef43e_row20_col0" class="data row20 col0" >Fabric Meta Data Release Tag</td>
#       <td id="T_ef43e_row20_col1" class="data row20 col1" >main</td>
#     </tr>
#   </tbody>
# </table>
# User: audreyf@illinois.edu bastion key is valid!
# Configuration is valid
# <style type="text/css">
# #T_9da16 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_9da16 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9da16 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_9da16_row0_col0, #T_9da16_row0_col1, #T_9da16_row1_col0, #T_9da16_row1_col1, #T_9da16_row2_col0, #T_9da16_row2_col1, #T_9da16_row3_col0, #T_9da16_row3_col1, #T_9da16_row4_col0, #T_9da16_row4_col1, #T_9da16_row5_col0, #T_9da16_row5_col1, #T_9da16_row6_col0, #T_9da16_row6_col1, #T_9da16_row7_col0, #T_9da16_row7_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_9da16">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9da16_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_9da16_row0_col1" class="data row0 col1" >d1035024-ba8f-4203-b038-632073474a82</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_9da16_row1_col1" class="data row1 col1" >qfabric-bb84-2</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_9da16_row2_col1" class="data row2 col1" >2026-07-08 16:08:19 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_9da16_row3_col1" class="data row3 col1" >2026-07-07 16:08:19 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_9da16_row4_col1" class="data row4 col1" >24f4c8f3-e872-492a-9a83-b48211a91966</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_9da16_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row6_col0" class="data row6 col0" >Email</td>
#       <td id="T_9da16_row6_col1" class="data row6 col1" >audreyf@illinois.edu</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row7_col0" class="data row7 col0" >UserId</td>
#       <td id="T_9da16_row7_col1" class="data row7 col1" >8616dd8c-5b61-45db-84bb-791c21e82a89</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9da16 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_9da16 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9da16 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_9da16_row0_col0, #T_9da16_row0_col1, #T_9da16_row1_col0, #T_9da16_row1_col1, #T_9da16_row2_col0, #T_9da16_row2_col1, #T_9da16_row3_col0, #T_9da16_row3_col1, #T_9da16_row4_col0, #T_9da16_row4_col1, #T_9da16_row5_col0, #T_9da16_row5_col1, #T_9da16_row6_col0, #T_9da16_row6_col1, #T_9da16_row7_col0, #T_9da16_row7_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_9da16">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9da16_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_9da16_row0_col1" class="data row0 col1" >d1035024-ba8f-4203-b038-632073474a82</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_9da16_row1_col1" class="data row1 col1" >qfabric-bb84-2</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_9da16_row2_col1" class="data row2 col1" >2026-07-08 16:08:19 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_9da16_row3_col1" class="data row3 col1" >2026-07-07 16:08:19 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_9da16_row4_col1" class="data row4 col1" >24f4c8f3-e872-492a-9a83-b48211a91966</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_9da16_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row6_col0" class="data row6 col0" >Email</td>
#       <td id="T_9da16_row6_col1" class="data row6 col1" >audreyf@illinois.edu</td>
#     </tr>
#     <tr>
#       <td id="T_9da16_row7_col0" class="data row7 col0" >UserId</td>
#       <td id="T_9da16_row7_col1" class="data row7 col1" >8616dd8c-5b61-45db-84bb-791c21e82a89</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 1 — Run BB84 under each classical-network condition
# Each condition impairs only TCP:5100 (the sifting channel); photons are untouched. Edit
# the list to taste — `delay_ms`, `jitter_ms`, `loss_pct`, or asymmetric `alice_delay_ms`/`bob_delay_ms`.

# %%
conditions = [
    {'name': 'baseline'},
    {'name': 'latency_25ms',     'delay_ms': 25},
    {'name': 'latency_100ms',    'delay_ms': 100},
    {'name': 'jitter_50pm20ms',  'delay_ms': 50, 'jitter_ms': 20},
    {'name': 'loss_1pct',        'loss_pct': 1.0},
    {'name': 'asymmetric_100_10','alice_delay_ms': 100, 'bob_delay_ms': 10},
]
rows = df.run_network_conditions_experiment(slice_obj, SCENARIO, conditions)
print(f'\n{len(rows)} conditions recorded -> results/network_effects.json')
# Out:
# ##### [1/6] classical condition: baseline #####
#   cleared classical netem on Alice and Bob
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3764
#   QBER:            0.0080
#   Secure key rate: 0.2933
#   Final key bits:  2933
#   Elapsed:         42.21s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9537 photons
# Bob: 9537 photons arrived, 7632 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7632
#   Sifted bits:            3764
#   QBER:                   0.0080
#   Secure key rate:        0.2933
#   Final key bits:         2933
#   Elapsed:                52.41s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7632
#   sifted_bits: 3764
#   qber: 0.007978723404255319
#   secure_key_rate: 0.2933
#   final_key_bits: 2933
#   elapsed_seconds: 52.412317752838135
#   baseline: QBER=0.007978723404255319, elapsed=52.412317752838135s, bits/s=55.96012780490284
#
# ##### [2/6] classical condition: latency_25ms #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 25ms
#   bob (enp7s0): netem delay 25ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3815
#   QBER:            0.0052
#   Secure key rate: 0.3109
#   Final key bits:  3109
#   Elapsed:         50.27s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9577 photons
# Bob: 9577 photons arrived, 7640 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7640
#   Sifted bits:            3815
#   QBER:                   0.0052
#   Secure key rate:        0.3109
#   Final key bits:         3109
#   Elapsed:                60.40s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7640
#   sifted_bits: 3815
#   qber: 0.005249343832020997
#   secure_key_rate: 0.3109
#   final_key_bits: 3109
#   elapsed_seconds: 60.40471172332764
#   latency_25ms: QBER=0.005249343832020997, elapsed=60.40471172332764s, bits/s=51.46949486722471
#
# ##### [3/6] classical condition: latency_100ms #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3793
#   QBER:            0.0053
#   Secure key rate: 0.3089
#   Final key bits:  3089
#   Elapsed:         80.89s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9512 photons
# Bob: 9512 photons arrived, 7618 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7618
#   Sifted bits:            3793
#   QBER:                   0.0053
#   Secure key rate:        0.3089
#   Final key bits:         3089
#   Elapsed:                90.94s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7618
#   sifted_bits: 3793
#   qber: 0.005277044854881266
#   secure_key_rate: 0.3089
#   final_key_bits: 3089
#   elapsed_seconds: 90.94468069076538
#   latency_100ms: QBER=0.005277044854881266, elapsed=90.94468069076538s, bits/s=33.9657028485632
#
# ##### [4/6] classical condition: jitter_50pm20ms #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 50ms 20ms
#   bob (enp7s0): netem delay 50ms 20ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3859
#   QBER:            0.0078
#   Secure key rate: 0.3017
#   Final key bits:  3017
#   Elapsed:         44.58s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9560 photons
# Bob: 9560 photons arrived, 7660 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7660
#   Sifted bits:            3859
#   QBER:                   0.0078
#   Secure key rate:        0.3017
#   Final key bits:         3017
#   Elapsed:                54.70s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7660
#   sifted_bits: 3859
#   qber: 0.007792207792207792
#   secure_key_rate: 0.3017
#   final_key_bits: 3017
#   elapsed_seconds: 54.700756788253784
#   jitter_50pm20ms: QBER=0.007792207792207792, elapsed=54.700756788253784s, bits/s=55.154629974842656
#
# ##### [5/6] classical condition: loss_1pct #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 1.0%
#   bob (enp7s0): netem loss 1.0%
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3919
#   QBER:            0.0102
#   Secure key rate: 0.2947
#   Final key bits:  2947
#   Elapsed:         40.15s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9566 photons
# Bob: 9566 photons arrived, 7641 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7641
#   Sifted bits:            3919
#   QBER:                   0.0102
#   Secure key rate:        0.2947
#   Final key bits:         2947
#   Elapsed:                50.30s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7641
#   sifted_bits: 3919
#   qber: 0.010230179028132993
#   secure_key_rate: 0.2947
#   final_key_bits: 2947
#   elapsed_seconds: 50.30346441268921
#   loss_1pct: QBER=0.010230179028132993, elapsed=50.30346441268921s, bits/s=58.584434181766014
#
# ##### [6/6] classical condition: asymmetric_100_10 #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 10ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '32:CA:F2:F8:00:90' --src-mac '2E:C6:67:6F:9F:11'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3811
#   QBER:            0.0131
#   Secure key rate: 0.2738
#   Final key bits:  2738
#   Elapsed:         63.98s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9548 photons
# Bob: 9548 photons arrived, 7686 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7686
#   Sifted bits:            3811
#   QBER:                   0.0131
#   Secure key rate:        0.2738
#   Final key bits:         2738
#   Elapsed:                74.12s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qfabric/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qfabric/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7686
#   sifted_bits: 3811
#   qber: 0.013123359580052493
#   secure_key_rate: 0.2738
#   final_key_bits: 2738
#   elapsed_seconds: 74.12490582466125
#   asymmetric_100_10: QBER=0.013123359580052493, elapsed=74.12490582466125s, bits/s=36.93765232534125
#   cleared classical netem on Alice and Bob
#
# Saved -> /home/fabric/work/qfabric/results/network_effects.json (6 conditions)
#
# 6 conditions recorded -> results/network_effects.json

# %% [markdown]
# ## Step 2 — Plots: throughput & time-to-key degrade, QBER stays flat
# Loads `results/network_effects.json` (so this also re-plots a saved run). The story:
# **bits/second and time-to-key respond to the classical channel; QBER does not** — the
# effect ideal-channel simulators miss.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
rows = json.loads((PROJECT_DIR / 'results' / 'network_effects.json').read_text())
ok = [r for r in rows if not r.get('error')]
names = [r['condition'] for r in ok]
bps   = [r.get('key_bits_per_sec', 0) for r in ok]
tts   = [r.get('elapsed_seconds', 0) for r in ok]
qber  = [r.get('qber', 0) * 100 for r in ok]

fig, ax = plt.subplots(1, 3, figsize=(15, 4.2))
ax[0].bar(names, bps, color='seagreen');   ax[0].set(ylabel='key bits / second', title='Throughput')
ax[1].bar(names, tts, color='steelblue');  ax[1].set(ylabel='seconds', title='Time to key')
ax[2].bar(names, qber, color='indianred'); ax[2].set(ylabel='QBER (%)', title='QBER (should be ~flat)')
for a in ax: a.tick_params(axis='x', rotation=35); a.grid(axis='y', alpha=0.3)
fig.suptitle('Classical-network effect on BB84 (QFabric on FABRIC)')
plt.tight_layout(); plt.show()

failed = [r['condition'] for r in rows if r.get('error')]
if failed:
    print('conditions that failed (e.g. timed out):', failed)

# %% [markdown]
# ## Step 3 — Table

# %%
import pandas as pd
pd.DataFrame(rows)[['condition','qber','sifted_bits','final_key_bits','elapsed_seconds','key_bits_per_sec']]
# Out:
#            condition      qber  sifted_bits  final_key_bits  elapsed_seconds  \
# 0           baseline  0.007979         3764            2933        52.412318
# 1       latency_25ms  0.005249         3815            3109        60.404712
# 2      latency_100ms  0.005277         3793            3089        90.944681
# 3    jitter_50pm20ms  0.007792         3859            3017        54.700757
# 4          loss_1pct  0.010230         3919            2947        50.303464
# 5  asymmetric_100_10  0.013123         3811            2738        74.124906
#
#    key_bits_per_sec
# 0         55.960128
# 1         51.469495
# 2         33.965703
# 3         55.154630
# 4         58.584434
# 5         36.937652

# %% [markdown]
# ---
# This is the headline result: QFabric measures classical-network impact on QKD throughput.
# Extend `conditions` (or add competing traffic) to map the operating envelope.
