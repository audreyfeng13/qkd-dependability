# %%
SLICE_NAME = 'qfabric-bb84-2'
SCENARIO   = 'validation/scenarios/fabric_1km.yml'

# %%
import os, sys, json
from pathlib import Path

PROJECT_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_DIR)); sys.path.insert(0, str(PROJECT_DIR / 'scripts'))
import deploy_fabric_modified as df

fablib = df.get_fablib()
slice_obj = fablib.get_slice(name=SLICE_NAME)
slice_obj.show()
# Out:
# <style type="text/css">
# #T_91895 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_91895 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_91895 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_91895_row0_col0, #T_91895_row0_col1, #T_91895_row1_col0, #T_91895_row1_col1, #T_91895_row2_col0, #T_91895_row2_col1, #T_91895_row3_col0, #T_91895_row3_col1, #T_91895_row4_col0, #T_91895_row4_col1, #T_91895_row5_col0, #T_91895_row5_col1, #T_91895_row6_col0, #T_91895_row6_col1, #T_91895_row7_col0, #T_91895_row7_col1, #T_91895_row8_col0, #T_91895_row8_col1, #T_91895_row9_col0, #T_91895_row9_col1, #T_91895_row10_col0, #T_91895_row10_col1, #T_91895_row11_col0, #T_91895_row11_col1, #T_91895_row12_col0, #T_91895_row12_col1, #T_91895_row13_col0, #T_91895_row13_col1, #T_91895_row14_col0, #T_91895_row14_col1, #T_91895_row15_col0, #T_91895_row15_col1, #T_91895_row16_col0, #T_91895_row16_col1, #T_91895_row17_col0, #T_91895_row17_col1, #T_91895_row18_col0, #T_91895_row18_col1, #T_91895_row19_col0, #T_91895_row19_col1, #T_91895_row20_col0, #T_91895_row20_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_91895">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_91895_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_91895_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_91895_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_91895_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_91895_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row4_col0" class="data row4 col0" >CEPH Manager</td>
#       <td id="T_91895_row4_col1" class="data row4 col1" >https://ceph-mgr.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row5_col0" class="data row5 col0" >Token File</td>
#       <td id="T_91895_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/id_token.json</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row6_col0" class="data row6 col0" >Project ID</td>
#       <td id="T_91895_row6_col1" class="data row6 col1" >24f4c8f3-e872-492a-9a83-b48211a91966</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row7_col0" class="data row7 col0" >Bastion Host</td>
#       <td id="T_91895_row7_col1" class="data row7 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row8_col0" class="data row8 col0" >Bastion Username</td>
#       <td id="T_91895_row8_col1" class="data row8 col1" >audreyf_0000527467</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row9_col0" class="data row9 col0" >Bastion Private Key File</td>
#       <td id="T_91895_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row10_col0" class="data row10 col0" >Slice Public Key File</td>
#       <td id="T_91895_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row11_col0" class="data row11 col0" >Slice Private Key File</td>
#       <td id="T_91895_row11_col1" class="data row11 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row12_col0" class="data row12 col0" >Sites to avoid</td>
#       <td id="T_91895_row12_col1" class="data row12 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_91895_row13_col0" class="data row13 col0" >SSH Command Line</td>
#       <td id="T_91895_row13_col1" class="data row13 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row14_col0" class="data row14 col0" >Log Level</td>
#       <td id="T_91895_row14_col1" class="data row14 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row15_col0" class="data row15 col0" >Log File</td>
#       <td id="T_91895_row15_col1" class="data row15 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row16_col0" class="data row16 col0" >Log Propagate</td>
#       <td id="T_91895_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row17_col0" class="data row17 col0" >Bastion SSH Config File</td>
#       <td id="T_91895_row17_col1" class="data row17 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row18_col0" class="data row18 col0" >Fabric Meta Data Release Tag</td>
#       <td id="T_91895_row18_col1" class="data row18 col1" >main</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row19_col0" class="data row19 col0" >Version</td>
#       <td id="T_91895_row19_col1" class="data row19 col1" >2.0.6</td>
#     </tr>
#     <tr>
#       <td id="T_91895_row20_col0" class="data row20 col0" >Data directory</td>
#       <td id="T_91895_row20_col1" class="data row20 col1" >/tmp/fablib</td>
#     </tr>
#   </tbody>
# </table>
# User: audreyf@illinois.edu bastion key is valid!
# Configuration is valid
# <style type="text/css">
# #T_1f1bb tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_1f1bb tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1f1bb caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_1f1bb_row0_col0, #T_1f1bb_row0_col1, #T_1f1bb_row1_col0, #T_1f1bb_row1_col1, #T_1f1bb_row2_col0, #T_1f1bb_row2_col1, #T_1f1bb_row3_col0, #T_1f1bb_row3_col1, #T_1f1bb_row4_col0, #T_1f1bb_row4_col1, #T_1f1bb_row5_col0, #T_1f1bb_row5_col1, #T_1f1bb_row6_col0, #T_1f1bb_row6_col1, #T_1f1bb_row7_col0, #T_1f1bb_row7_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_1f1bb">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1f1bb_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_1f1bb_row0_col1" class="data row0 col1" >d8ea8804-1e65-4186-a902-d6006de32667</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_1f1bb_row1_col1" class="data row1 col1" >qfabric-bb84-2</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_1f1bb_row2_col1" class="data row2 col1" >2026-08-04 21:27:56 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_1f1bb_row3_col1" class="data row3 col1" >2026-07-20 21:27:56 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_1f1bb_row4_col1" class="data row4 col1" >24f4c8f3-e872-492a-9a83-b48211a91966</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_1f1bb_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row6_col0" class="data row6 col0" >Email</td>
#       <td id="T_1f1bb_row6_col1" class="data row6 col1" >audreyf@illinois.edu</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row7_col0" class="data row7 col0" >UserId</td>
#       <td id="T_1f1bb_row7_col1" class="data row7 col1" >8616dd8c-5b61-45db-84bb-791c21e82a89</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1f1bb tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_1f1bb tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1f1bb caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_1f1bb_row0_col0, #T_1f1bb_row0_col1, #T_1f1bb_row1_col0, #T_1f1bb_row1_col1, #T_1f1bb_row2_col0, #T_1f1bb_row2_col1, #T_1f1bb_row3_col0, #T_1f1bb_row3_col1, #T_1f1bb_row4_col0, #T_1f1bb_row4_col1, #T_1f1bb_row5_col0, #T_1f1bb_row5_col1, #T_1f1bb_row6_col0, #T_1f1bb_row6_col1, #T_1f1bb_row7_col0, #T_1f1bb_row7_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_1f1bb">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1f1bb_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_1f1bb_row0_col1" class="data row0 col1" >d8ea8804-1e65-4186-a902-d6006de32667</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_1f1bb_row1_col1" class="data row1 col1" >qfabric-bb84-2</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_1f1bb_row2_col1" class="data row2 col1" >2026-08-04 21:27:56 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_1f1bb_row3_col1" class="data row3 col1" >2026-07-20 21:27:56 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_1f1bb_row4_col1" class="data row4 col1" >24f4c8f3-e872-492a-9a83-b48211a91966</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_1f1bb_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row6_col0" class="data row6 col0" >Email</td>
#       <td id="T_1f1bb_row6_col1" class="data row6 col1" >audreyf@illinois.edu</td>
#     </tr>
#     <tr>
#       <td id="T_1f1bb_row7_col0" class="data row7 col0" >UserId</td>
#       <td id="T_1f1bb_row7_col1" class="data row7 col1" >8616dd8c-5b61-45db-84bb-791c21e82a89</td>
#     </tr>
#   </tbody>
# </table>

# %%
#BASELINE RUNS

import json
import pandas as pd
import deploy_fabric_modified as deploy

# run 10 baseline conditions
conditions = [{'name': f'baseline_run_{i}'} for i in range(1, 11)]

rows = deploy.run_network_conditions_experiment(
    slice_obj,
    SCENARIO,
    conditions=conditions
)

# save to json
with open('/home/fabric/work/qkd-pqc-dependability/results/baseline_results.json', 'w') as f:
    json.dump(rows, f, indent=2)

# save to csv
df_baseline = pd.DataFrame(rows)
df_baseline.to_csv('/home/fabric/work/qkd-pqc-dependability/results/baseline_results.csv', index=False)

print(f"Completed {len(rows)} baseline runs")
print(df_baseline[['qber', 'key_bits_per_sec', 'elapsed_seconds']].describe())

# %%
#SINGLE PARAMETER SWEEPS

import json
import pandas as pd
import deploy_fabric_modified as deploy

rows = deploy.run_single_axis_sweeps(
    slice_obj,
    scenario_path="validation/scenarios/fabric_1km.yml",
    n_runs=5,
    port=5100,
    save_json=True,
)

df_baseline = pd.DataFrame(rows)
df_baseline.to_csv('/home/fabric/work/qkd-pqc-dependability/results/single_axis_sweeps.csv', index=False)
print(f"Completed {len(rows)} single axis runs")
# Out:
# ##### axis=latency_ms value=1 (run 1/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 1ms
#   bob (enp7s0): netem delay 1ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3785
#   QBER:            0.0053
#   Secure key rate: 0.3082
#   Final key bits:  3082
#   Elapsed:         39.57s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9545 photons
# Bob: 9545 photons arrived, 7605 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7605
#   Sifted bits:            3785
#   QBER:                   0.0053
#   Secure key rate:        0.3082
#   Final key bits:         3082
#   Elapsed:                49.54s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7605
#   sifted_bits: 3785
#   qber: 0.005291005291005291
#   secure_key_rate: 0.3082
#   final_key_bits: 3082
#   elapsed_seconds: 49.53661799430847
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=1 (run 2/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 1ms
#   bob (enp7s0): netem delay 1ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3818
#   QBER:            0.0105
#   Secure key rate: 0.2859
#   Final key bits:  2859
#   Elapsed:         39.83s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9608 photons
# Bob: 9608 photons arrived, 7672 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7672
#   Sifted bits:            3818
#   QBER:                   0.0105
#   Secure key rate:        0.2859
#   Final key bits:         2859
#   Elapsed:                49.80s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7672
#   sifted_bits: 3818
#   qber: 0.010498687664041995
#   secure_key_rate: 0.2859
#   final_key_bits: 2859
#   elapsed_seconds: 49.79785871505737
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=1 (run 3/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 1ms
#   bob (enp7s0): netem delay 1ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3776
#   QBER:            0.0080
#   Secure key rate: 0.2944
#   Final key bits:  2944
#   Elapsed:         39.70s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9498 photons
# Bob: 9498 photons arrived, 7623 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7623
#   Sifted bits:            3776
#   QBER:                   0.0080
#   Secure key rate:        0.2944
#   Final key bits:         2944
#   Elapsed:                49.67s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7623
#   sifted_bits: 3776
#   qber: 0.007957559681697613
#   secure_key_rate: 0.2944
#   final_key_bits: 2944
#   elapsed_seconds: 49.670618534088135
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=1 (run 4/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 1ms
#   bob (enp7s0): netem delay 1ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3853
#   QBER:            0.0078
#   Secure key rate: 0.3011
#   Final key bits:  3011
#   Elapsed:         39.67s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9542 photons
# Bob: 9542 photons arrived, 7607 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7607
#   Sifted bits:            3853
#   QBER:                   0.0078
#   Secure key rate:        0.3011
#   Final key bits:         3011
#   Elapsed:                49.66s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7607
#   sifted_bits: 3853
#   qber: 0.007792207792207792
#   secure_key_rate: 0.3011
#   final_key_bits: 3011
#   elapsed_seconds: 49.65957188606262
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=1 (run 5/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 1ms
#   bob (enp7s0): netem delay 1ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3869
#   QBER:            0.0078
#   Secure key rate: 0.3025
#   Final key bits:  3025
#   Elapsed:         39.36s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9587 photons
# Bob: 9587 photons arrived, 7661 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7661
#   Sifted bits:            3869
#   QBER:                   0.0078
#   Secure key rate:        0.3025
#   Final key bits:         3025
#   Elapsed:                49.33s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7661
#   sifted_bits: 3869
#   qber: 0.007772020725388601
#   secure_key_rate: 0.3025
#   final_key_bits: 3025
#   elapsed_seconds: 49.33382272720337
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=50 (run 1/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 50ms
#   bob (enp7s0): netem delay 50ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3861
#   QBER:            0.0181
#   Secure key rate: 0.2565
#   Final key bits:  2565
#   Elapsed:         59.39s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9520 photons
# Bob: 9520 photons arrived, 7625 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7625
#   Sifted bits:            3861
#   QBER:                   0.0181
#   Secure key rate:        0.2565
#   Final key bits:         2565
#   Elapsed:                69.32s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7625
#   sifted_bits: 3861
#   qber: 0.018134715025906734
#   secure_key_rate: 0.2565
#   final_key_bits: 2565
#   elapsed_seconds: 69.31813788414001
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=50 (run 2/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 50ms
#   bob (enp7s0): netem delay 50ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3829
#   QBER:            0.0052
#   Secure key rate: 0.3121
#   Final key bits:  3121
#   Elapsed:         58.28s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9543 photons
# Bob: 9543 photons arrived, 7620 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7620
#   Sifted bits:            3829
#   QBER:                   0.0052
#   Secure key rate:        0.3121
#   Final key bits:         3121
#   Elapsed:                68.20s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7620
#   sifted_bits: 3829
#   qber: 0.005235602094240838
#   secure_key_rate: 0.3121
#   final_key_bits: 3121
#   elapsed_seconds: 68.20243000984192
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=50 (run 3/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 50ms
#   bob (enp7s0): netem delay 50ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3777
#   QBER:            0.0133
#   Secure key rate: 0.2708
#   Final key bits:  2708
#   Elapsed:         59.52s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9566 photons
# Bob: 9566 photons arrived, 7622 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7622
#   Sifted bits:            3777
#   QBER:                   0.0133
#   Secure key rate:        0.2708
#   Final key bits:         2708
#   Elapsed:                69.45s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7622
#   sifted_bits: 3777
#   qber: 0.013262599469496022
#   secure_key_rate: 0.2708
#   final_key_bits: 2708
#   elapsed_seconds: 69.45015263557434
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=50 (run 4/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 50ms
#   bob (enp7s0): netem delay 50ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3769
#   QBER:            0.0239
#   Secure key rate: 0.2286
#   Final key bits:  2286
#   Elapsed:         52.73s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9551 photons
# Bob: 9551 photons arrived, 7662 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7662
#   Sifted bits:            3769
#   QBER:                   0.0239
#   Secure key rate:        0.2286
#   Final key bits:         2286
#   Elapsed:                62.65s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7662
#   sifted_bits: 3769
#   qber: 0.023936170212765957
#   secure_key_rate: 0.2286
#   final_key_bits: 2286
#   elapsed_seconds: 62.64900231361389
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=50 (run 5/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 50ms
#   bob (enp7s0): netem delay 50ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3820
#   QBER:            0.0052
#   Secure key rate: 0.3113
#   Final key bits:  3113
#   Elapsed:         59.87s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9554 photons
# Bob: 9554 photons arrived, 7676 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7676
#   Sifted bits:            3820
#   QBER:                   0.0052
#   Secure key rate:        0.3113
#   Final key bits:         3113
#   Elapsed:                69.79s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7676
#   sifted_bits: 3820
#   qber: 0.005235602094240838
#   secure_key_rate: 0.3113
#   final_key_bits: 3113
#   elapsed_seconds: 69.78905940055847
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=100 (run 1/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3862
#   QBER:            0.0052
#   Secure key rate: 0.3150
#   Final key bits:  3150
#   Elapsed:         84.20s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9561 photons
# Bob: 9561 photons arrived, 7675 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7675
#   Sifted bits:            3862
#   QBER:                   0.0052
#   Secure key rate:        0.3150
#   Final key bits:         3150
#   Elapsed:                94.07s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7675
#   sifted_bits: 3862
#   qber: 0.0051813471502590676
#   secure_key_rate: 0.315
#   final_key_bits: 3150
#   elapsed_seconds: 94.0736620426178
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=100 (run 2/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3869
#   QBER:            0.0181
#   Secure key rate: 0.2571
#   Final key bits:  2571
#   Elapsed:         84.93s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9540 photons
# Bob: 9540 photons arrived, 7668 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7668
#   Sifted bits:            3869
#   QBER:                   0.0181
#   Secure key rate:        0.2571
#   Final key bits:         2571
#   Elapsed:                94.80s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7668
#   sifted_bits: 3869
#   qber: 0.018134715025906734
#   secure_key_rate: 0.2571
#   final_key_bits: 2571
#   elapsed_seconds: 94.80069255828857
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=100 (run 3/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3795
#   QBER:            0.0079
#   Secure key rate: 0.2960
#   Final key bits:  2960
#   Elapsed:         78.26s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9544 photons
# Bob: 9544 photons arrived, 7670 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7670
#   Sifted bits:            3795
#   QBER:                   0.0079
#   Secure key rate:        0.2960
#   Final key bits:         2960
#   Elapsed:                88.13s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7670
#   sifted_bits: 3795
#   qber: 0.0079155672823219
#   secure_key_rate: 0.296
#   final_key_bits: 2960
#   elapsed_seconds: 88.1339020729065
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=100 (run 4/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3784
#   QBER:            0.0079
#   Secure key rate: 0.2951
#   Final key bits:  2951
#   Elapsed:         81.86s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9549 photons
# Bob: 9549 photons arrived, 7663 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7663
#   Sifted bits:            3784
#   QBER:                   0.0079
#   Secure key rate:        0.2951
#   Final key bits:         2951
#   Elapsed:                91.74s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7663
#   sifted_bits: 3784
#   qber: 0.007936507936507936
#   secure_key_rate: 0.2951
#   final_key_bits: 2951
#   elapsed_seconds: 91.7364068031311
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=100 (run 5/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3832
#   QBER:            0.0104
#   Secure key rate: 0.2871
#   Final key bits:  2871
#   Elapsed:         82.42s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9529 photons
# Bob: 9529 photons arrived, 7629 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7629
#   Sifted bits:            3832
#   QBER:                   0.0104
#   Secure key rate:        0.2871
#   Final key bits:         2871
#   Elapsed:                92.29s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7629
#   sifted_bits: 3832
#   qber: 0.010443864229765013
#   secure_key_rate: 0.2871
#   final_key_bits: 2871
#   elapsed_seconds: 92.29108262062073
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=150 (run 1/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 150ms
#   bob (enp7s0): netem delay 150ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3782
#   QBER:            0.0159
#   Secure key rate: 0.2603
#   Final key bits:  2603
#   Elapsed:         101.14s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9526 photons
# Bob: 9526 photons arrived, 7602 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7602
#   Sifted bits:            3782
#   QBER:                   0.0159
#   Secure key rate:        0.2603
#   Final key bits:         2603
#   Elapsed:                110.96s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7602
#   sifted_bits: 3782
#   qber: 0.015873015873015872
#   secure_key_rate: 0.2603
#   final_key_bits: 2603
#   elapsed_seconds: 110.96290946006775
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=150 (run 2/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 150ms
#   bob (enp7s0): netem delay 150ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3834
#   QBER:            0.0131
#   Secure key rate: 0.2757
#   Final key bits:  2757
#   Elapsed:         102.06s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9558 photons
# Bob: 9558 photons arrived, 7609 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7609
#   Sifted bits:            3834
#   QBER:                   0.0131
#   Secure key rate:        0.2757
#   Final key bits:         2757
#   Elapsed:                111.89s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7609
#   sifted_bits: 3834
#   qber: 0.013054830287206266
#   secure_key_rate: 0.2757
#   final_key_bits: 2757
#   elapsed_seconds: 111.89155554771423
#   cleared classical netem on Alice and Bob
#
# ##### axis=latency_ms value=150 (run 3/5) #####
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 150ms
#   bob (enp7s0): netem delay 150ms
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3850
#   QBER:            0.0052
#   Secure key rate: 0.3140
# ...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4199
#   QBER:            0.0119
#   Secure key rate: 0.3074
#   Final key bits:  3074
#   Elapsed:         38.75s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9570 photons
# Bob: 9570 photons arrived, 8595 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 8595
#   Sifted bits:            4199
#   QBER:                   0.0119
#   Secure key rate:        0.3074
#   Final key bits:         3074
#   Elapsed:                48.72s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 8595
#   sifted_bits: 4199
#   qber: 0.011933174224343675
#   secure_key_rate: 0.3074
#   final_key_bits: 3074
#   elapsed_seconds: 48.722283601760864
#
# ##### axis=efficiency value=1.0 (run 1/5) #####
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4721
#   QBER:            0.0085
#   Secure key rate: 0.3649
#   Final key bits:  3649
#   Elapsed:         39.18s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9551 photons
# Bob: 9551 photons arrived, 9551 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9551
#   Sifted bits:            4721
#   QBER:                   0.0085
#   Secure key rate:        0.3649
#   Final key bits:         3649
#   Elapsed:                49.17s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9551
#   sifted_bits: 4721
#   qber: 0.00847457627118644
#   secure_key_rate: 0.3649
#   final_key_bits: 3649
#   elapsed_seconds: 49.17095613479614
#
# ##### axis=efficiency value=1.0 (run 2/5) #####
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4758
#   QBER:            0.0063
#   Secure key rate: 0.3809
#   Final key bits:  3809
#   Elapsed:         38.05s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9528 photons
# Bob: 9528 photons arrived, 9528 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9528
#   Sifted bits:            4758
#   QBER:                   0.0063
#   Secure key rate:        0.3809
#   Final key bits:         3809
#   Elapsed:                48.02s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9528
#   sifted_bits: 4758
#   qber: 0.00631578947368421
#   secure_key_rate: 0.3809
#   final_key_bits: 3809
#   elapsed_seconds: 48.02488160133362
#
# ##### axis=efficiency value=1.0 (run 3/5) #####
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4747
#   QBER:            0.0127
#   Secure key rate: 0.3435
#   Final key bits:  3435
#   Elapsed:         39.15s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9557 photons
# Bob: 9557 photons arrived, 9557 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9557
#   Sifted bits:            4747
#   QBER:                   0.0127
#   Secure key rate:        0.3435
#   Final key bits:         3435
#   Elapsed:                49.13s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9557
#   sifted_bits: 4747
#   qber: 0.012658227848101266
#   secure_key_rate: 0.3435
#   final_key_bits: 3435
#   elapsed_seconds: 49.12716031074524
#
# ##### axis=efficiency value=1.0 (run 4/5) #####
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4807
#   QBER:            0.0042
#   Secure key rate: 0.3989
#   Final key bits:  3989
#   Elapsed:         38.34s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9555 photons
# Bob: 9555 photons arrived, 9555 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9555
#   Sifted bits:            4807
#   QBER:                   0.0042
#   Secure key rate:        0.3989
#   Final key bits:         3989
#   Elapsed:                48.32s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9555
#   sifted_bits: 4807
#   qber: 0.004166666666666667
#   secure_key_rate: 0.3989
#   final_key_bits: 3989
#   elapsed_seconds: 48.315556049346924
#
# ##### axis=efficiency value=1.0 (run 5/5) #####
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4837
#   QBER:            0.0186
#   Secure key rate: 0.3189
#   Final key bits:  3189
#   Elapsed:         39.27s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9534 photons
# Bob: 9534 photons arrived, 9534 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9534
#   Sifted bits:            4837
#   QBER:                   0.0186
#   Secure key rate:        0.3189
#   Final key bits:         3189
#   Elapsed:                49.25s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9534
#   sifted_bits: 4837
#   qber: 0.018633540372670808
#   secure_key_rate: 0.3189
#   final_key_bits: 3189
#   elapsed_seconds: 49.2507221698761
#   cleared classical netem on Alice and Bob
#
# Saved -> /home/fabric/work/qkd-pqc-dependability/results/single_axis_sweeps.json (205 rows)
# Completed 205 single axis runs

# %%
def is_success(rows, qber_threshold=0.11, key_rate_floor=1.0):
    """Label each row success/fail per F: {QBER >= 11% OR KeyRate -> 0}.
    key_rate_floor is a placeholder for "approaches 0" — confirm with Dr. Cao.
    Rows with no measurement (prior 'error' field) are marked fail, not success.
    """
    for row in rows:
        if row.get("error"):
            row["success"] = False
            row["fail_reason"] = row["error"]
            continue

        qber = row.get("qber")
        key_rate = row.get("key_bits_per_sec")

        if qber is None or key_rate is None:
            row["success"] = False
            row["fail_reason"] = "missing qber or key_bits_per_sec"
            continue

        qber_fail = qber >= qber_threshold
        rate_fail = key_rate < key_rate_floor

        row["success"] = not (qber_fail or rate_fail)
        if qber_fail and rate_fail:
            row["fail_reason"] = "qber_and_rate"
        elif qber_fail:
            row["fail_reason"] = "qber"
        elif rate_fail:
            row["fail_reason"] = "key_rate"
        else:
            row["fail_reason"] = None

    return rows

# %%
rows = is_success(rows)
df_baseline = pd.DataFrame(rows)
df_baseline.to_csv('/home/fabric/work/qkd-pqc-dependability/results/single_axis_sweeps.csv', index=False)
print(df_baseline['success'].value_counts())
# Out:
# success
# True     203
# False      2
# Name: count, dtype: int64

# %%
prob_success = df_baseline['success'].value_counts()/df_baseline.shape[0]
print(prob_success)
# Out:
# success
# True     0.990244
# False    0.009756
# Name: count, dtype: float64

# %%
summary = (df_baseline.rename(columns={'axis': 'sweep_axis'})
           .groupby(['sweep_axis', 'value'])
           .agg(
               qber_mean=('qber', 'mean'),
               qber_std=('qber', 'std'),
               key_rate_mean=('key_bits_per_sec', 'mean'),
               key_rate_std=('key_bits_per_sec', 'std'),
               final_key_bits_mean=('final_key_bits', 'mean'),
               final_key_bits_std=('final_key_bits', 'std'),
               success_prob=('success', 'mean'),
               n=('success', 'size'),
           )
           .reset_index()
           .rename(columns={'sweep_axis': 'axis'}))

# %%
print(summary)
summary.to_csv('/home/fabric/work/qkd-pqc-dependability/results/single_axis_sweep_summary.csv', index=False)

# %%
import matplotlib.pyplot as plt
from scipy import stats

axes_list = summary['axis'].unique()
n_axes = len(axes_list)

fig, axs = plt.subplots(n_axes, 2, figsize=(10, 3 * n_axes))

for i, axis_name in enumerate(axes_list):
    d = summary[summary['axis'] == axis_name].sort_values('value').copy()

    # 95% CI via t-distribution, using per-point n (falls back safely if any point has n=1)
    t_crit = d['n'].apply(lambda n: stats.t.ppf(0.975, n - 1) if n > 1 else 0)
    qber_ci = t_crit * d['qber_std'] / d['n']**0.5
    rate_ci = t_crit * d['key_rate_std'] / d['n']**0.5

    axs[i, 0].errorbar(d['value'], d['qber_mean'], yerr=qber_ci, marker='o', capsize=3)
    axs[i, 0].set_title(f'{axis_name}: QBER (95% CI)')
    axs[i, 0].set_xlabel(axis_name)
    axs[i, 0].set_ylabel('QBER')
    axs[i, 0].axhline(0.11, color='red', linestyle='--', linewidth=1, label='11% threshold')
    axs[i, 0].legend(fontsize=8)

    axs[i, 1].errorbar(d['value'], d['key_rate_mean'], yerr=rate_ci, marker='o', capsize=3, color='steelblue')
    axs[i, 1].set_title(f'{axis_name}: Key Rate (95% CI)')
    axs[i, 1].set_xlabel(axis_name)
    axs[i, 1].set_ylabel('key bits/sec')

    if axis_name == 'dark_count_rate_hz':
        axs[i, 0].set_xscale('log')
        axs[i, 1].set_xscale('log')

plt.tight_layout()
plt.savefig('/home/fabric/work/qkd-pqc-dependability/results/single_axis_sweeps_plot.png', dpi=150)
plt.show()

# %%
def fit_linear_regression(summary_df, axis_name, y_col='qber_mean'):
    """Fit OLS linear regression of y_col vs value, for one sweep axis.

    Returns dict with slope, intercept, r_squared, p_value, std_err, and the
    fitted x/y arrays for plotting. y_col should be one of the *_mean columns
    in your summary dataframe (e.g. 'qber_mean', 'key_rate_mean').
    """
    from scipy import stats
    import numpy as np

    d = summary_df[summary_df['axis'] == axis_name].sort_values('value')
    x = d['value'].to_numpy(dtype=float)
    y = d[y_col].to_numpy(dtype=float)

    mask = ~np.isnan(y)
    x, y = x[mask], y[mask]

    if len(x) < 2:
        raise ValueError(f"Not enough valid points to fit regression for axis={axis_name}, y_col={y_col} (n={len(x)})")

    result = stats.linregress(x, y)

    return {
        "axis": axis_name,
        "y_col": y_col,
        "slope": result.slope,
        "intercept": result.intercept,
        "r_squared": result.rvalue ** 2,
        "p_value": result.pvalue,
        "std_err": result.stderr,
        "x": x,
        "y_fit": result.intercept + result.slope * x,
        "n_points": len(x),
    }

# %%
def fit_quadratic_regression(summary_df, axis_name, y_col='qber_mean'):
    """Fit y = a*x^2 + b*x + c via least squares, for one sweep axis."""
    import numpy as np

    d = summary_df[summary_df['axis'] == axis_name].sort_values('value')
    x = d['value'].to_numpy(dtype=float)
    y = d[y_col].to_numpy(dtype=float)

    mask = ~np.isnan(y)
    x, y = x[mask], y[mask]

    if len(x) < 3:
        raise ValueError(f"Need >=3 points for quadratic fit (axis={axis_name}, y_col={y_col}, n={len(x)})")

    coeffs = np.polyfit(x, y, 2)  # [a, b, c]
    y_fit = np.polyval(coeffs, x)

    ss_res = np.sum((y - y_fit) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - ss_res / ss_tot if ss_tot > 0 else float('nan')

    return {
        "axis": axis_name, "y_col": y_col,
        "a": coeffs[0], "b": coeffs[1], "c": coeffs[2],
        "r_squared": r_squared,
        "x": x, "y_fit": y_fit, "n_points": len(x),
    }


def fit_exponential_regression(summary_df, axis_name, y_col='qber_mean'):
    """Fit y = a * exp(b*x) via log-linearization (log(y) = log(a) + b*x).
    Requires all y > 0 — drops non-positive points with a warning since log
    is undefined there.
    """
    import numpy as np

    d = summary_df[summary_df['axis'] == axis_name].sort_values('value')
    x = d['value'].to_numpy(dtype=float)
    y = d[y_col].to_numpy(dtype=float)

    mask = ~np.isnan(y) & (y > 0)
    n_dropped = np.sum(~np.isnan(y)) - np.sum(mask)
    if n_dropped > 0:
        print(f"  (exp fit {axis_name}/{y_col}: dropped {n_dropped} non-positive/NaN points)")
    x, y = x[mask], y[mask]

    if len(x) < 2:
        raise ValueError(f"Not enough positive points for exponential fit (axis={axis_name}, y_col={y_col}, n={len(x)})")

    log_y = np.log(y)
    b, log_a = np.polyfit(x, log_y, 1)
    a = np.exp(log_a)
    y_fit = a * np.exp(b * x)

    ss_res = np.sum((y - y_fit) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - ss_res / ss_tot if ss_tot > 0 else float('nan')

    return {
        "axis": axis_name, "y_col": y_col,
        "a": a, "b": b,
        "r_squared": r_squared,
        "x": x, "y_fit": y_fit, "n_points": len(x),
    }

# %%
def fit_exponential_regression_log_x(summary_df, axis_name, y_col='qber_mean'):
    """Same as fit_exponential_regression, but regresses against log10(value)
    instead of raw value. Use for axes swept multiplicatively/log-spaced
    (e.g. dark_count_rate_hz spanning 100 to 1e6).
    """
    import numpy as np

    d = summary_df[summary_df['axis'] == axis_name].sort_values('value')
    x_raw = d['value'].to_numpy(dtype=float)
    y = d[y_col].to_numpy(dtype=float)

    mask = ~np.isnan(y) & (y > 0) & (x_raw > 0)
    n_dropped = np.sum(~np.isnan(y)) - np.sum(mask)
    if n_dropped > 0:
        print(f"  (exp-logx fit {axis_name}/{y_col}: dropped {n_dropped} non-positive/NaN points)")
    x_raw, y = x_raw[mask], y[mask]

    if len(x_raw) < 2:
        raise ValueError(f"Not enough positive points for exp-logx fit (axis={axis_name}, y_col={y_col}, n={len(x_raw)})")

    x = np.log10(x_raw)
    log_y = np.log(y)
    b, log_a = np.polyfit(x, log_y, 1)
    a = np.exp(log_a)
    y_fit = a * np.exp(b * x)

    ss_res = np.sum((y - y_fit) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - ss_res / ss_tot if ss_tot > 0 else float('nan')

    return {
        "axis": axis_name, "y_col": y_col,
        "a": a, "b": b,
        "r_squared": r_squared,
        "x": x_raw, "x_log": x, "y_fit": y_fit, "n_points": len(x_raw),
    }


def fit_quadratic_regression_log_x(summary_df, axis_name, y_col='qber_mean'):
    """Same as fit_quadratic_regression, but fits y = a*log10(x)^2 + b*log10(x) + c."""
    import numpy as np

    d = summary_df[summary_df['axis'] == axis_name].sort_values('value')
    x_raw = d['value'].to_numpy(dtype=float)
    y = d[y_col].to_numpy(dtype=float)

    mask = ~np.isnan(y) & (x_raw > 0)
    x_raw, y = x_raw[mask], y[mask]

    if len(x_raw) < 3:
        raise ValueError(f"Need >=3 points for quad-logx fit (axis={axis_name}, y_col={y_col}, n={len(x_raw)})")

    x = np.log10(x_raw)
    coeffs = np.polyfit(x, y, 2)
    y_fit = np.polyval(coeffs, x)

    ss_res = np.sum((y - y_fit) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - ss_res / ss_tot if ss_tot > 0 else float('nan')

    return {
        "axis": axis_name, "y_col": y_col,
        "a": coeffs[0], "b": coeffs[1], "c": coeffs[2],
        "r_squared": r_squared,
        "x": x_raw, "x_log": x, "y_fit": y_fit, "n_points": len(x_raw),
    }

# %%
def spearman_correlation(summary_df, axis_name, y_col='qber_mean'):
    """Spearman rank correlation between axis value and y_col, for one axis.
    Use when the relationship might be monotonic but not linear — doesn't
    assume any particular functional form (unlike the regression fits).
    """
    from scipy import stats
    import numpy as np

    d = summary_df[summary_df['axis'] == axis_name].sort_values('value')
    x = d['value'].to_numpy(dtype=float)
    y = d[y_col].to_numpy(dtype=float)

    mask = ~np.isnan(y)
    x, y = x[mask], y[mask]

    if len(x) < 3:
        raise ValueError(f"Need >=3 points for Spearman (axis={axis_name}, y_col={y_col}, n={len(x)})")

    rho, p_value = stats.spearmanr(x, y)

    return {
        "axis": axis_name, "y_col": y_col,
        "rho": rho, "p_value": p_value, "n_points": len(x),
    }


def one_way_anova(raw_df, axis_name, y_col='qber', group_col='value'):
    """One-way ANOVA testing whether y_col's mean differs across the levels
    (values) of one sweep axis, using the raw per-run data (not the
    aggregated summary — ANOVA needs the individual run values per group,
    not pre-averaged ones).
    """
    from scipy import stats
    import numpy as np

    d = raw_df[raw_df['axis'] == axis_name] if 'axis' in raw_df.columns else raw_df[raw_df['sweep_axis'] == axis_name]

    groups = [
        g[y_col].dropna().to_numpy(dtype=float)
        for _, g in d.groupby(group_col)
    ]
    groups = [g for g in groups if len(g) > 0]

    if len(groups) < 2:
        raise ValueError(f"Need >=2 groups with data for ANOVA (axis={axis_name}, y_col={y_col})")

    f_stat, p_value = stats.f_oneway(*groups)

    return {
        "axis": axis_name, "y_col": y_col,
        "f_stat": f_stat, "p_value": p_value,
        "n_groups": len(groups),
        "group_sizes": [len(g) for g in groups],
    }

# %%
def levene_test(raw_df, axis_name, y_col='qber', group_col='value'):
    """Levene's test for homogeneity of variance across levels of one axis.
    Run this before trusting an ANOVA result — ANOVA assumes equal variance
    across groups; if Levene's p < 0.05, that assumption is violated and the
    ANOVA p-value is less trustworthy (consider Welch's ANOVA or Kruskal-Wallis
    instead, which don't require it).
    """
    from scipy import stats
    import numpy as np

    d = raw_df[raw_df['axis'] == axis_name] if 'axis' in raw_df.columns else raw_df[raw_df['sweep_axis'] == axis_name]

    groups = [
        g[y_col].dropna().to_numpy(dtype=float)
        for _, g in d.groupby(group_col)
    ]
    groups = [g for g in groups if len(g) > 0]

    if len(groups) < 2:
        raise ValueError(f"Need >=2 groups with data for Levene's test (axis={axis_name}, y_col={y_col})")

    stat, p_value = stats.levene(*groups)

    return {
        "axis": axis_name, "y_col": y_col,
        "levene_stat": stat, "p_value": p_value,
        "n_groups": len(groups),
        "group_sizes": [len(g) for g in groups],
    }

# %%
for axis in axis_names:
    print(f"\n===== {axis} =====")
    for y_summary, y_raw in [('key_rate_mean', 'key_bits_per_sec'), ('qber_mean', 'qber')]:
        print(f"  -- {y_raw} --")
        try:
            lin = fit_linear_regression(summary, axis, y_col=y_summary)
            print(f"  linear:   slope={lin['slope']:.5f}, R²={lin['r_squared']:.3f}, p={lin['p_value']:.4f}")
        except ValueError as e:
            print(f"  linear:   skipped ({e})")
        try:
            if axis == 'dark_count_rate_hz':
                quad = fit_quadratic_regression_log_x(summary, axis, y_col=y_summary)
            else:
                quad = fit_quadratic_regression(summary, axis, y_col=y_summary)
            print(f"  quad:     a={quad['a']:.5f}, b={quad['b']:.5f}, c={quad['c']:.5f}, R²={quad['r_squared']:.3f}")
        except ValueError as e:
            print(f"  quad:     skipped ({e})")
        try:
            if axis == 'dark_count_rate_hz':
                exp = fit_exponential_regression_log_x(summary, axis, y_col=y_summary)
            else:
                exp = fit_exponential_regression(summary, axis, y_col=y_summary)
            print(f"  exp:      a={exp['a']:.5f}, b={exp['b']:.5f}, R²={exp['r_squared']:.3f}")
        except ValueError as e:
            print(f"  exp:      skipped ({e})")
        try:
            spear = spearman_correlation(summary, axis, y_col=y_summary)
            print(f"  spearman: rho={spear['rho']:.3f}, p={spear['p_value']:.4f}")
        except ValueError as e:
            print(f"  spearman: skipped ({e})")
        try:
            anova = one_way_anova(df_baseline, axis, y_col=y_raw)
            print(f"  anova:    F={anova['f_stat']:.3f}, p={anova['p_value']:.4f}, groups={anova['group_sizes']}")
        except ValueError as e:
            print(f"  anova:    skipped ({e})")
        try:
            lev = levene_test(df_baseline, axis, y_col=y_raw)
            print(f"  levene:   stat={lev['levene_stat']:.3f}, p={lev['p_value']:.4f}")
        except ValueError as e:
            print(f"  levene:   skipped ({e})")

# %%
def standardized_coefficients(summary_df, axis_names, y_col):
    """Standardized (beta) linear regression coefficients across multiple axes,
    so their coefficients are comparable despite different units/scales
    (e.g. loss_pct in % vs distance_km in km).

    Standardizes x and y (z-score) per axis, then fits linear regression —
    the resulting slope is the standardized beta: how many std devs y changes
    per 1 std dev change in x. Returns a list of dicts sorted by |beta|
    descending, so the most impactful axis (in relative terms) is first.
    """
    from scipy import stats
    import numpy as np

    results = []
    for axis in axis_names:
        d = summary_df[summary_df['axis'] == axis].sort_values('value')
        x = d['value'].to_numpy(dtype=float)
        y = d[y_col].to_numpy(dtype=float)

        mask = ~np.isnan(y)
        x, y = x[mask], y[mask]

        if len(x) < 2:
            results.append({"axis": axis, "y_col": y_col, "beta": None,
                             "r_squared": None, "p_value": None,
                             "note": f"skipped (n={len(x)})"})
            continue

        x_std, y_std = np.std(x), np.std(y)
        if x_std == 0 or y_std == 0:
            results.append({"axis": axis, "y_col": y_col, "beta": None,
                             "r_squared": None, "p_value": None,
                             "note": "skipped (zero variance in x or y)"})
            continue

        x_z = (x - np.mean(x)) / x_std
        y_z = (y - np.mean(y)) / y_std

        fit = stats.linregress(x_z, y_z)

        results.append({
            "axis": axis, "y_col": y_col,
            "beta": fit.slope,           # standardized coefficient
            "r_squared": fit.rvalue ** 2,
            "p_value": fit.pvalue,
            "n_points": len(x),
            "note": None,
        })

    results.sort(key=lambda r: abs(r["beta"]) if r["beta"] is not None else -1, reverse=True)
    return results

# %%
beta_key_rate = standardized_coefficients(summary, axis_names, y_col='key_rate_mean')
beta_qber = standardized_coefficients(summary, axis_names, y_col='qber_mean')

for r in beta_key_rate:
    if r["beta"] is not None:
        print(f"{r['axis']:25s} beta={r['beta']:+.3f}  R²={r['r_squared']:.3f}  p={r['p_value']:.4f}")
    else:
        print(f"{r['axis']:25s} {r['note']}")

# %%
def quadratic_vs_linear_test(raw_df, x_col, y_col):
    """
    Nested F-test comparing linear vs quadratic regression.

    H0: quadratic term is unnecessary (linear model is sufficient)
    H1: quadratic term significantly improves the fit

    If p < 0.05, quadratic regression is a meaningful improvement.
    """
    import numpy as np
    import statsmodels.api as sm
    from statsmodels.stats.anova import anova_lm

    d = summary[[x_col, y_col]].dropna()

    x = d[x_col].to_numpy(dtype=float)
    y = d[y_col].to_numpy(dtype=float)

    if len(x) < 4:
        raise ValueError("Need at least 4 points for model comparison")

    # Linear model: y = b0 + b1*x
    X_linear = sm.add_constant(x)
    linear_model = sm.OLS(y, X_linear).fit()

    # Quadratic model: y = b0 + b1*x + b2*x^2
    X_quad = np.column_stack([x, x**2])
    X_quad = sm.add_constant(X_quad)
    quad_model = sm.OLS(y, X_quad).fit()

    # Nested F-test
    comparison = anova_lm(linear_model, quad_model)

    return {
        "x_col": x_col,
        "y_col": y_col,
        "linear_R2": linear_model.rsquared,
        "linear_adj_R2": linear_model.rsquared_adj,
        "quad_R2": quad_model.rsquared,
        "quad_adj_R2": quad_model.rsquared_adj,
        "quadratic_coef": quad_model.params[2],
        "quadratic_p_value": quad_model.pvalues[2],
        "F_stat": comparison.iloc[1]["F"],
        "F_p_value": comparison.iloc[1]["Pr(>F)"],
        "quadratic_better": comparison.iloc[1]["Pr(>F)"] < 0.05,
        "n": len(x)
    }

# %%
axes = [
    "latency_ms",
    "jitter_ms",
    "loss_pct",
    "attenuation_db_per_km",
    "distance_km",
    "polarization_fidelity",
    "dark_count_rate_hz",
    "efficiency"
]

for axis in axes:
    r = quadratic_vs_linear_test(
        summary,
        x_col="value",
        y_col="key_rate_mean"
    )

    print(
        axis,
        "quad better:", r["quadratic_better"],
        "p =", r["F_p_value"]
    )

for axis in axes:
    r = quadratic_vs_linear_test(
        df_baseline,
        x_col="value",
        y_col="qber_mean"
    )

    print(
        axis,
        "quad better:", r["quadratic_better"],
        "p =", r["F_p_value"]
    )

# %%
pf_vals = [0.8, 0.9, 1.0]
eff_vals = [0.5, 0.8, 1.0]
loss_vals = [1, 10, 15]
latency_vals = [1, 100, 200]

joint_results = {}
joint_results['pf_x_efficiency'] = deploy.run_joint_axis_sweep(slice_obj, 'polarization_fidelity', 'efficiency', pf_vals, eff_vals)
joint_results['pf_x_loss']       = deploy.run_joint_axis_sweep(slice_obj, 'polarization_fidelity', 'loss_pct', pf_vals, loss_vals)
joint_results['pf_x_latency']    = deploy.run_joint_axis_sweep(slice_obj, 'polarization_fidelity', 'latency_ms', pf_vals, latency_vals)
joint_results['loss_x_efficiency']    = deploy.run_joint_axis_sweep(slice_obj, 'loss_pct', 'efficiency', loss_vals, eff_vals)
joint_results['latency_x_efficiency'] = deploy.run_joint_axis_sweep(slice_obj, 'latency_ms', 'efficiency', latency_vals, eff_vals)
# Out:
#   cleared classical netem on Alice and Bob
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.8, efficiency=0.5 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2324
#   QBER:            0.0819
#   Secure key rate: 0.0381
#   Final key bits:  381
#   Elapsed:         38.78s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9559 photons
# Bob: 9559 photons arrived, 4689 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4689
#   Sifted bits:            2324
#   QBER:                   0.0819
#   Secure key rate:        0.0381
#   Final key bits:         381
#   Elapsed:                48.77s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4689
#   sifted_bits: 2324
#   qber: 0.08189655172413793
#   secure_key_rate: 0.0381
#   final_key_bits: 381
#   elapsed_seconds: 48.77016806602478
#
# ##### polarization_fidelity=0.8, efficiency=0.5 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2434
#   QBER:            0.1029
#   Secure key rate: 0.0096
#   Final key bits:  96
#   Elapsed:         37.98s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9507 photons
# Bob: 9507 photons arrived, 4768 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4768
#   Sifted bits:            2434
#   QBER:                   0.1029
#   Secure key rate:        0.0096
#   Final key bits:         96
#   Elapsed:                47.95s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4768
#   sifted_bits: 2434
#   qber: 0.102880658436214
#   secure_key_rate: 0.0096
#   final_key_bits: 96
#   elapsed_seconds: 47.94981336593628
#
# ##### polarization_fidelity=0.8, efficiency=0.5 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2398
#   QBER:            0.1464
#   Secure key rate: 0.0000
#   Final key bits:  0
#   Elapsed:         38.44s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9518 photons
# Bob: 9518 photons arrived, 4709 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4709
#   Sifted bits:            2398
#   QBER:                   0.1464
#   Secure key rate:        0.0000
#   Final key bits:         0
#   Elapsed:                48.41s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4709
#   sifted_bits: 2398
#   qber: 0.14644351464435146
#   secure_key_rate: 0.0
#   final_key_bits: 0
#   elapsed_seconds: 48.406437158584595
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.8, efficiency=0.8 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3871
#   QBER:            0.0982
#   Secure key rate: 0.0256
#   Final key bits:  256
#   Elapsed:         39.71s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9564 photons
# Bob: 9564 photons arrived, 7616 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7616
#   Sifted bits:            3871
#   QBER:                   0.0982
#   Secure key rate:        0.0256
#   Final key bits:         256
#   Elapsed:                49.68s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7616
#   sifted_bits: 3871
#   qber: 0.09819121447028424
#   secure_key_rate: 0.0256
#   final_key_bits: 256
#   elapsed_seconds: 49.68483090400696
#
# ##### polarization_fidelity=0.8, efficiency=0.8 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3815
#   QBER:            0.1234
#   Secure key rate: 0.0000
#   Final key bits:  0
#   Elapsed:         39.27s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9552 photons
# Bob: 9552 photons arrived, 7669 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7669
#   Sifted bits:            3815
#   QBER:                   0.1234
#   Secure key rate:        0.0000
#   Final key bits:         0
#   Elapsed:                49.25s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7669
#   sifted_bits: 3815
#   qber: 0.12335958005249344
#   secure_key_rate: 0.0
#   final_key_bits: 0
#   elapsed_seconds: 49.24721312522888
#
# ##### polarization_fidelity=0.8, efficiency=0.8 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3828
#   QBER:            0.0681
#   Secure key rate: 0.0974
#   Final key bits:  974
#   Elapsed:         39.34s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9573 photons
# Bob: 9573 photons arrived, 7667 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7667
#   Sifted bits:            3828
#   QBER:                   0.0681
#   Secure key rate:        0.0974
#   Final key bits:         974
#   Elapsed:                49.32s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7667
#   sifted_bits: 3828
#   qber: 0.06806282722513089
#   secure_key_rate: 0.0974
#   final_key_bits: 974
#   elapsed_seconds: 49.31967115402222
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.8, efficiency=1.0 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4785
#   QBER:            0.0983
#   Secure key rate: 0.0312
#   Final key bits:  312
#   Elapsed:         38.47s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9561 photons
# Bob: 9561 photons arrived, 9561 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9561
#   Sifted bits:            4785
#   QBER:                   0.0983
#   Secure key rate:        0.0312
#   Final key bits:         312
#   Elapsed:                48.44s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9561
#   sifted_bits: 4785
#   qber: 0.09832635983263599
#   secure_key_rate: 0.0312
#   final_key_bits: 312
#   elapsed_seconds: 48.441476583480835
#
# ##### polarization_fidelity=0.8, efficiency=1.0 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4837
#   QBER:            0.0994
#   Secure key rate: 0.0287
#   Final key bits:  287
#   Elapsed:         39.62s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9537 photons
# Bob: 9537 photons arrived, 9537 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9537
#   Sifted bits:            4837
#   QBER:                   0.0994
#   Secure key rate:        0.0287
#   Final key bits:         287
#   Elapsed:                49.61s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9537
#   sifted_bits: 4837
#   qber: 0.09937888198757763
#   secure_key_rate: 0.0287
#   final_key_bits: 287
#   elapsed_seconds: 49.6121723651886
#
# ##### polarization_fidelity=0.8, efficiency=1.0 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4770
#   QBER:            0.0922
#   Secure key rate: 0.0481
#   Final key bits:  481
#   Elapsed:         39.50s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9571 photons
# Bob: 9571 photons arrived, 9571 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9571
#   Sifted bits:            4770
#   QBER:                   0.0922
#   Secure key rate:        0.0481
#   Final key bits:         481
#   Elapsed:                49.47s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9571
#   sifted_bits: 4770
#   qber: 0.09224318658280922
#   secure_key_rate: 0.0481
#   final_key_bits: 481
#   elapsed_seconds: 49.470486879348755
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.9, efficiency=0.5 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2382
#   QBER:            0.0462
#   Secure key rate: 0.0985
#   Final key bits:  985
#   Elapsed:         38.88s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9551 photons
# Bob: 9551 photons arrived, 4711 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4711
#   Sifted bits:            2382
#   QBER:                   0.0462
#   Secure key rate:        0.0985
#   Final key bits:         985
#   Elapsed:                48.86s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4711
#   sifted_bits: 2382
#   qber: 0.046218487394957986
#   secure_key_rate: 0.0985
#   final_key_bits: 985
#   elapsed_seconds: 48.8626172542572
#
# ##### polarization_fidelity=0.9, efficiency=0.5 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2329
#   QBER:            0.0819
#   Secure key rate: 0.0382
#   Final key bits:  382
#   Elapsed:         38.37s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9573 photons
# Bob: 9573 photons arrived, 4690 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4690
#   Sifted bits:            2329
#   QBER:                   0.0819
#   Secure key rate:        0.0382
#   Final key bits:         382
#   Elapsed:                48.35s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4690
#   sifted_bits: 2329
#   qber: 0.08189655172413793
#   secure_key_rate: 0.0382
#   final_key_bits: 382
#   elapsed_seconds: 48.3498420715332
#
# ##### polarization_fidelity=0.9, efficiency=0.5 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2411
#   QBER:            0.0747
#   Secure key rate: 0.0506
#   Final key bits:  506
#   Elapsed:         42.10s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9547 photons
# Bob: 9547 photons arrived, 4746 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4746
#   Sifted bits:            2411
#   QBER:                   0.0747
#   Secure key rate:        0.0506
#   Final key bits:         506
#   Elapsed:                52.07s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4746
#   sifted_bits: 2411
#   qber: 0.07468879668049792
#   secure_key_rate: 0.0506
#   final_key_bits: 506
#   elapsed_seconds: 52.07250213623047
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.9, efficiency=0.8 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3778
#   QBER:            0.0451
#   Secure key rate: 0.1597
#   Final key bits:  1597
#   Elapsed:         38.89s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9563 photons
# Bob: 9563 photons arrived, 7602 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7602
#   Sifted bits:            3778
#   QBER:                   0.0451
#   Secure key rate:        0.1597
#   Final key bits:         1597
#   Elapsed:                48.85s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7602
#   sifted_bits: 3778
#   qber: 0.04509283819628647
#   secure_key_rate: 0.1597
#   final_key_bits: 1597
#   elapsed_seconds: 48.854628801345825
#
# ##### polarization_fidelity=0.9, efficiency=0.8 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3765
#   QBER:            0.0319
#   Secure key rate: 0.2006
#   Final key bits:  2006
#   Elapsed:         38.92s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9535 photons
# Bob: 9535 photons arrived, 7623 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7623
#   Sifted bits:            3765
#   QBER:                   0.0319
#   Secure key rate:        0.2006
#   Final key bits:         2006
#   Elapsed:                48.89s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7623
#   sifted_bits: 3765
#   qber: 0.031914893617021274
#   secure_key_rate: 0.2006
#   final_key_bits: 2006
#   elapsed_seconds: 48.89102387428284
#
# ##### polarization_fidelity=0.9, efficiency=0.8 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3851
#   QBER:            0.0519
#   Secure key rate: 0.1423
#   Final key bits:  1423
#   Elapsed:         37.80s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9535 photons
# Bob: 9535 photons arrived, 7637 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7637
#   Sifted bits:            3851
#   QBER:                   0.0519
#   Secure key rate:        0.1423
#   Final key bits:         1423
#   Elapsed:                47.78s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7637
#   sifted_bits: 3851
#   qber: 0.05194805194805195
#   secure_key_rate: 0.1423
#   final_key_bits: 1423
#   elapsed_seconds: 47.77826166152954
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.9, efficiency=1.0 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4778
#   QBER:            0.0461
#   Secure key rate: 0.1981
#   Final key bits:  1981
#   Elapsed:         40.89s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9560 photons
# Bob: 9560 photons arrived, 9560 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9560
#   Sifted bits:            4778
#   QBER:                   0.0461
#   Secure key rate:        0.1981
#   Final key bits:         1981
#   Elapsed:                50.86s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9560
#   sifted_bits: 4778
#   qber: 0.04612159329140461
#   secure_key_rate: 0.1981
#   final_key_bits: 1981
#   elapsed_seconds: 50.860034704208374
#
# ##### polarization_fidelity=0.9, efficiency=1.0 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4779
#   QBER:            0.0566
#   Secure key rate: 0.1601
#   Final key bits:  1601
#   Elapsed:         39.17s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9554 photons
# Bob: 9554 photons arrived, 9554 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9554
#   Sifted bits:            4779
#   QBER:                   0.0566
#   Secure key rate:        0.1601
#   Final key bits:         1601
#   Elapsed:                49.14s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9554
#   sifted_bits: 4779
#   qber: 0.05660377358490566
#   secure_key_rate: 0.1601
#   final_key_bits: 1601
#   elapsed_seconds: 49.144330739974976
#
# ##### polarization_fidelity=0.9, efficiency=1.0 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4755
# ...
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 10%
#   bob (enp7s0): netem loss 10%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=1.0, loss_pct=10 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3828
#   QBER:            0.0000
#   Secure key rate: 0.3446
#   Final key bits:  3446
#   Elapsed:         54.58s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9551 photons
# Bob: 9551 photons arrived, 7643 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7643
#   Sifted bits:            3828
#   QBER:                   0.0000
#   Secure key rate:        0.3446
#   Final key bits:         3446
#   Elapsed:                64.56s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7643
#   sifted_bits: 3828
#   qber: 0.0
#   secure_key_rate: 0.3446
#   final_key_bits: 3446
#   elapsed_seconds: 64.55815410614014
#
# ##### polarization_fidelity=1.0, loss_pct=10 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3803
#   QBER:            0.0000
#   Secure key rate: 0.3423
#   Final key bits:  3423
#   Elapsed:         45.28s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9534 photons
# Bob: 9534 photons arrived, 7624 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7624
#   Sifted bits:            3803
#   QBER:                   0.0000
#   Secure key rate:        0.3423
#   Final key bits:         3423
#   Elapsed:                55.25s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7624
#   sifted_bits: 3803
#   qber: 0.0
#   secure_key_rate: 0.3423
#   final_key_bits: 3423
#   elapsed_seconds: 55.24984073638916
#
# ##### polarization_fidelity=1.0, loss_pct=10 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3726
#   QBER:            0.0000
#   Secure key rate: 0.3354
#   Final key bits:  3354
#   Elapsed:         43.80s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9540 photons
# Bob: 9540 photons arrived, 7604 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7604
#   Sifted bits:            3726
#   QBER:                   0.0000
#   Secure key rate:        0.3354
#   Final key bits:         3354
#   Elapsed:                53.77s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7604
#   sifted_bits: 3726
#   qber: 0.0
#   secure_key_rate: 0.3354
#   final_key_bits: 3354
#   elapsed_seconds: 53.77480626106262
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 15%
#   bob (enp7s0): netem loss 15%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=1.0, loss_pct=15 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3777
#   QBER:            0.0000
#   Secure key rate: 0.3400
#   Final key bits:  3400
#   Elapsed:         80.06s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9594 photons
# Bob: 9594 photons arrived, 7703 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7703
#   Sifted bits:            3777
#   QBER:                   0.0000
#   Secure key rate:        0.3400
#   Final key bits:         3400
#   Elapsed:                90.04s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7703
#   sifted_bits: 3777
#   qber: 0.0
#   secure_key_rate: 0.34
#   final_key_bits: 3400
#   elapsed_seconds: 90.04252219200134
#
# ##### polarization_fidelity=1.0, loss_pct=15 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/ubuntu/qfabric/qne/cli.py", line 154, in <module>
#     main()
#   File "/home/ubuntu/qfabric/qne/cli.py", line 148, in main
#     _run_alice(args)
#   File "/home/ubuntu/qfabric/qne/cli.py", line 121, in _run_alice
#     metrics = alice.run()
#   File "/home/ubuntu/qfabric/qne/alice.py", line 87, in run
#     self._run_sifting()
#   File "/home/ubuntu/qfabric/qne/alice.py", line 158, in _run_sifting
#     msg = channel.recv_message()
#   File "/home/ubuntu/qfabric/qne/channel.py", line 51, in recv_message
#     header = self._recv_exact(4)
#   File "/home/ubuntu/qfabric/qne/channel.py", line 60, in _recv_exact
#     chunk = self._sock.recv(n - len(buf))
# TimeoutError: timed out
# Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
#   cleared classical netem on Alice and Bob
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 8
#       4 latency_vals = [1, 100, 200]
#       5
#       6 joint_results = {}
#       7 joint_results['pf_x_efficiency'] = deploy.run_joint_axis_sweep(slice_obj, 'polarization_fidelity', 'efficiency', pf_vals, eff_vals)
# ----> 8 joint_results['pf_x_loss']       = deploy.run_joint_axis_sweep(slice_obj, 'polarization_fidelity', 'loss_pct', pf_vals, loss_vals)
#       9 joint_results['pf_x_latency']    = deploy.run_joint_axis_sweep(slice_obj, 'polarization_fidelity', 'latency_ms', pf_vals, latency_vals)
#      10 joint_results['loss_x_efficiency']    = deploy.run_joint_axis_sweep(slice_obj, 'loss_pct', 'efficiency', loss_vals, eff_vals)
#      11 joint_results['latency_x_efficiency'] = deploy.run_joint_axis_sweep(slice_obj, 'latency_ms', 'efficiency', latency_vals, eff_vals)
#
# File ~/work/qkd-pqc-dependability/scripts/deploy_fabric_modified.py:1357, in run_joint_axis_sweep(slice_obj, axis1, axis2, values1, values2, scenario_path, n_runs, port, save_json)
#    1355 for run_idx in range(1, n_runs + 1):
#    1356     print(f"\n##### {axis1}={v1}, {axis2}={v2} (run {run_idx}/{n_runs}) #####")
# -> 1357     row = _run_one(run_path, {axis1: v1, axis2: v2}, run_idx)
#    1358     rows.append(row)
#    1359     if save_json:
#
# File ~/work/qkd-pqc-dependability/scripts/deploy_fabric_modified.py:1294, in run_joint_axis_sweep.<locals>._run_one(scenario_path_for_run, row_meta, run_idx)
#    1292 run_start = _time.time()
#    1293 try:
# -> 1294     run_bb84(slice_obj, scenario_path_for_run, alice_mac, bob_mac,
#    1295              sw_alice_mac=sw_alice_mac, bob_data_ip="10.10.1.2")
#    1296 except Exception as e:
#    1297     print(f"  !! run failed under {row_meta}: {e}")
#
# File ~/work/qkd-pqc-dependability/scripts/deploy_fabric_modified.py:725, in run_bb84(slice_obj, scenario_path, alice_mac, bob_mac, sw_alice_mac, bob_data_ip)
#     723 time.sleep(5)
#     724 try:
# --> 725     bob_result = bob_thread.result()
#     726     print("  Bob finished")
#     727     print(f"  Bob output: {str(bob_result[0])[:500]}")
#
# File /opt/conda/lib/python3.13/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File /opt/conda/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     357 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     358     if timeout is None:
# --> 359         waiter.acquire()
#     360         gotit = True
#     361     else:
#
# KeyboardInterrupt:

# %%
import json
import shutil
from pathlib import Path

results_dir = Path('/home/fabric/work/qkd-pqc-dependability/results')
src = results_dir / 'joint_polarization_fidelity_x_loss_pct.json'

with open(src) as f:
    pf_x_loss_data = json.load(f)

print(f"Rows saved so far: {len(pf_x_loss_data)}")
print(f"Last completed combo: {pf_x_loss_data[-1] if pf_x_loss_data else 'none'}")

# make a timestamped backup copy so nothing later can overwrite/corrupt it
import time
backup_path = results_dir / f"joint_pf_x_loss_BACKUP_{int(time.time())}.json"
shutil.copy(src, backup_path)
print(f"Backup saved -> {backup_path}")

results_dir = Path('/home/fabric/work/qkd-pqc-dependability/results')
src = results_dir / 'joint_polarization_fidelity_x_efficiency.json'

with open(src) as f:
    pf_x_efficiency_data = json.load(f)

print(f"Rows saved so far: {len(pf_x_efficiency_data)}")
print(f"Last completed combo: {pf_x_efficiency_data[-1] if pf_x_efficiency_data else 'none'}")

# make a timestamped backup copy so nothing later can overwrite/corrupt it
import time
backup_path = results_dir / f"pf_x_efficiency_data_BACKUP_{int(time.time())}.json"
shutil.copy(src, backup_path)
print(f"Backup saved -> {backup_path}")
# Out:
# Rows saved so far: 25
# Last completed combo: {'polarization_fidelity': 1.0, 'loss_pct': 15, 'run': 1, 'qber': 0.0, 'sifted_bits': 3777, 'final_key_bits': 3400, 'secure_key_rate': 0.34, 'elapsed_seconds': 90.04252219200134, 'key_bits_per_sec': 37.759937385472625}
# Backup saved -> /home/fabric/work/qkd-pqc-dependability/results/joint_pf_x_loss_BACKUP_1785300255.json
# Rows saved so far: 27
# Last completed combo: {'polarization_fidelity': 1.0, 'efficiency': 1.0, 'run': 3, 'qber': 0.0, 'sifted_bits': 4816, 'final_key_bits': 4335, 'secure_key_rate': 0.4335, 'elapsed_seconds': 50.01752686500549, 'key_bits_per_sec': 86.66961906573115}
# Backup saved -> /home/fabric/work/qkd-pqc-dependability/results/pf_x_efficiency_data_BACKUP_1785300255.json

# %%
import importlib
import deploy_fabric_modified as deploy
importlib.reload(deploy)
print(hasattr(deploy, 'run_joint_axis_sweep'))
print(hasattr(deploy, 'clear_classical_netem'))
print(hasattr(deploy, 'apply_classical_netem'))

print(deploy.__file__)
print('clear_classical_netem' in dir())
# Out:
# True
# True
# True
# /home/fabric/work/qkd-pqc-dependability/scripts/deploy_fabric_modified.py
# False

# %%
pf_vals = [0.8, 0.9, 1.0]
eff_vals = [0.5, 0.8, 1.0]
loss_vals = [1, 10, 15]
latency_vals = [1, 100, 200]

joint_results = {}
joint_results['pf_x_efficiency'] = deploy.run_joint_axis_sweep(slice_obj, 'polarization_fidelity', 'efficiency', pf_vals, eff_vals)
joint_results['pf_x_loss'] = deploy.run_joint_axis_sweep(slice_obj, 'polarization_fidelity', 'loss_pct', pf_vals, loss_vals)
# Out:
# Resuming: 27 rows loaded, 27 successful runs will be skipped
# skip (already done): polarization_fidelity=0.8, efficiency=0.5
# skip (already done): polarization_fidelity=0.8, efficiency=0.8
# skip (already done): polarization_fidelity=0.8, efficiency=1.0
# skip (already done): polarization_fidelity=0.9, efficiency=0.5
# skip (already done): polarization_fidelity=0.9, efficiency=0.8
# skip (already done): polarization_fidelity=0.9, efficiency=1.0
# skip (already done): polarization_fidelity=1.0, efficiency=0.5
# skip (already done): polarization_fidelity=1.0, efficiency=0.8
# skip (already done): polarization_fidelity=1.0, efficiency=1.0
#   cleared classical netem on Alice and Bob
#
# Saved -> /home/fabric/work/qkd-pqc-dependability/results/joint_polarization_fidelity_x_efficiency.json (27 rows total)
# Resuming: 25 rows loaded, 25 successful runs will be skipped
# skip (already done): polarization_fidelity=0.8, loss_pct=1
# skip (already done): polarization_fidelity=0.8, loss_pct=10
# skip (already done): polarization_fidelity=0.8, loss_pct=15
# skip (already done): polarization_fidelity=0.9, loss_pct=1
# skip (already done): polarization_fidelity=0.9, loss_pct=10
# skip (already done): polarization_fidelity=0.9, loss_pct=15
# skip (already done): polarization_fidelity=1.0, loss_pct=1
# skip (already done): polarization_fidelity=1.0, loss_pct=10
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 15%
#   bob (enp7s0): netem loss 15%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
# skip (already done): polarization_fidelity=1.0, loss_pct=15, run 1
#
# ##### polarization_fidelity=1.0, loss_pct=15 (run 2/3) #####
# pkill: killing pid 108823 failed: Operation not permitted
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
#     !! port 5100 still held on bob after 15s
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3777
#   QBER:            0.0000
#   Secure key rate: 0.3400
#   Final key bits:  3400
#   Elapsed:         163.15s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9525 photons
# Bob: 9525 photons arrived, 7616 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7616
#   Sifted bits:            3777
#   QBER:                   0.0000
#   Secure key rate:        0.3400
#   Final key bits:         3400
#   Elapsed:                173.16s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7616
#   sifted_bits: 3777
#   qber: 0.0
#   secure_key_rate: 0.34
#   final_key_bits: 3400
#   elapsed_seconds: 173.1561839580536
#
# ##### polarization_fidelity=1.0, loss_pct=15 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3823
#   QBER:            0.0000
#   Secure key rate: 0.3441
#   Final key bits:  3441
#   Elapsed:         87.51s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9576 photons
# Bob: 9576 photons arrived, 7626 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7626
#   Sifted bits:            3823
#   QBER:                   0.0000
#   Secure key rate:        0.3441
#   Final key bits:         3441
#   Elapsed:                97.50s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7626
#   sifted_bits: 3823
#   qber: 0.0
#   secure_key_rate: 0.3441
#   final_key_bits: 3441
#   elapsed_seconds: 97.50177955627441
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# Saved -> /home/fabric/work/qkd-pqc-dependability/results/joint_polarization_fidelity_x_loss_pct.json (27 rows total)

# %%
joint_results['pf_x_latency'] = deploy.run_joint_axis_sweep(slice_obj, 'polarization_fidelity', 'latency_ms', pf_vals, latency_vals)
# Out:
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 1ms
#   bob (enp7s0): netem delay 1ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.8, latency_ms=1 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3819
#   QBER:            0.0997
#   Secure key rate: 0.0218
#   Final key bits:  218
#   Elapsed:         39.74s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9563 photons
# Bob: 9563 photons arrived, 7631 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7631
#   Sifted bits:            3819
#   QBER:                   0.0997
#   Secure key rate:        0.0218
#   Final key bits:         218
#   Elapsed:                49.74s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7631
#   sifted_bits: 3819
#   qber: 0.09973753280839895
#   secure_key_rate: 0.0218
#   final_key_bits: 218
#   elapsed_seconds: 49.73721432685852
#
# ##### polarization_fidelity=0.8, latency_ms=1 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3830
#   QBER:            0.1097
#   Secure key rate: 0.0007
#   Final key bits:  7
#   Elapsed:         38.98s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9539 photons
# Bob: 9539 photons arrived, 7670 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7670
#   Sifted bits:            3830
#   QBER:                   0.1097
#   Secure key rate:        0.0007
#   Final key bits:         7
#   Elapsed:                48.98s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7670
#   sifted_bits: 3830
#   qber: 0.10966057441253264
#   secure_key_rate: 0.0007
#   final_key_bits: 7
#   elapsed_seconds: 48.98432374000549
#
# ##### polarization_fidelity=0.8, latency_ms=1 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3810
#   QBER:            0.0814
#   Secure key rate: 0.0637
#   Final key bits:  637
#   Elapsed:         40.01s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9545 photons
# Bob: 9545 photons arrived, 7586 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7586
#   Sifted bits:            3810
#   QBER:                   0.0814
#   Secure key rate:        0.0637
#   Final key bits:         637
#   Elapsed:                50.02s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7586
#   sifted_bits: 3810
#   qber: 0.08136482939632546
#   secure_key_rate: 0.0637
#   final_key_bits: 637
#   elapsed_seconds: 50.016152143478394
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.8, latency_ms=100 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3850
#   QBER:            0.1039
#   Secure key rate: 0.0130
#   Final key bits:  130
#   Elapsed:         83.47s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9542 photons
# Bob: 9542 photons arrived, 7582 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7582
#   Sifted bits:            3850
#   QBER:                   0.1039
#   Secure key rate:        0.0130
#   Final key bits:         130
#   Elapsed:                93.37s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7582
#   sifted_bits: 3850
#   qber: 0.1038961038961039
#   secure_key_rate: 0.013
#   final_key_bits: 130
#   elapsed_seconds: 93.37374949455261
#
# ##### polarization_fidelity=0.8, latency_ms=100 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3871
#   QBER:            0.1008
#   Secure key rate: 0.0198
#   Final key bits:  198
#   Elapsed:         84.72s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9534 photons
# Bob: 9534 photons arrived, 7607 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7607
#   Sifted bits:            3871
#   QBER:                   0.1008
#   Secure key rate:        0.0198
#   Final key bits:         198
#   Elapsed:                94.62s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7607
#   sifted_bits: 3871
#   qber: 0.10077519379844961
#   secure_key_rate: 0.0198
#   final_key_bits: 198
#   elapsed_seconds: 94.62004327774048
#
# ##### polarization_fidelity=0.8, latency_ms=100 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3736
#   QBER:            0.0804
#   Secure key rate: 0.0647
#   Final key bits:  647
#   Elapsed:         82.26s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9527 photons
# Bob: 9527 photons arrived, 7522 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7522
#   Sifted bits:            3736
#   QBER:                   0.0804
#   Secure key rate:        0.0647
#   Final key bits:         647
#   Elapsed:                92.17s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7522
#   sifted_bits: 3736
#   qber: 0.08042895442359249
#   secure_key_rate: 0.0647
#   final_key_bits: 647
#   elapsed_seconds: 92.1738612651825
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 200ms
#   bob (enp7s0): netem delay 200ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.8, latency_ms=200 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3892
#   QBER:            0.0951
#   Secure key rate: 0.0327
#   Final key bits:  327
#   Elapsed:         123.73s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9544 photons
# Bob: 9544 photons arrived, 7650 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7650
#   Sifted bits:            3892
#   QBER:                   0.0951
#   Secure key rate:        0.0327
#   Final key bits:         327
#   Elapsed:                133.53s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7650
#   sifted_bits: 3892
#   qber: 0.09511568123393316
#   secure_key_rate: 0.0327
#   final_key_bits: 327
#   elapsed_seconds: 133.5271384716034
#
# ##### polarization_fidelity=0.8, latency_ms=200 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3841
#   QBER:            0.0885
#   Secure key rate: 0.0473
#   Final key bits:  473
#   Elapsed:         122.26s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9539 photons
# Bob: 9539 photons arrived, 7659 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7659
#   Sifted bits:            3841
#   QBER:                   0.0885
#   Secure key rate:        0.0473
#   Final key bits:         473
#   Elapsed:                132.06s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7659
#   sifted_bits: 3841
#   qber: 0.08854166666666667
#   secure_key_rate: 0.0473
#   final_key_bits: 473
#   elapsed_seconds: 132.0572009086609
#
# ##### polarization_fidelity=0.8, latency_ms=200 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3824
#   QBER:            0.0916
#   Secure key rate: 0.0400
#   Final key bits:  400
#   Elapsed:         116.01s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9561 photons
# Bob: 9561 photons arrived, 7602 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7602
#   Sifted bits:            3824
#   QBER:                   0.0916
#   Secure key rate:        0.0400
#   Final key bits:         400
#   Elapsed:                125.82s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7602
#   sifted_bits: 3824
#   qber: 0.09162303664921466
#   secure_key_rate: 0.04
#   final_key_bits: 400
#   elapsed_seconds: 125.8232638835907
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 1ms
#   bob (enp7s0): netem delay 1ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.9, latency_ms=1 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3851
#   QBER:            0.0519
#   Secure key rate: 0.1423
#   Final key bits:  1423
#   Elapsed:         38.44s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9542 photons
# Bob: 9542 photons arrived, 7607 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7607
#   Sifted bits:            3851
#   QBER:                   0.0519
#   Secure key rate:        0.1423
#   Final key bits:         1423
#   Elapsed:                48.44s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7607
#   sifted_bits: 3851
#   qber: 0.05194805194805195
#   secure_key_rate: 0.1423
#   final_key_bits: 1423
#   elapsed_seconds: 48.442665338516235
#
# ##### polarization_fidelity=0.9, latency_ms=1 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3890
#   QBER:            0.0514
#   Secure key rate: 0.1453
#   Final key bits:  1453
#   Elapsed:         44.04s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9542 photons
# Bob: 9542 photons arrived, 7626 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7626
#   Sifted bits:            3890
#   QBER:                   0.0514
#   Secure key rate:        0.1453
#   Final key bits:         1453
#   Elapsed:                54.04s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7626
#   sifted_bits: 3890
#   qber: 0.05141388174807198
#   secure_key_rate: 0.1453
#   final_key_bits: 1453
#   elapsed_seconds: 54.04131817817688
#
# ##### polarization_fidelity=0.9, latency_ms=1 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3808
#   QBER:            0.0316
#   Secure key rate: 0.2041
#   Final key bits:  2041
#   Elapsed:         40.25s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9544 photons
# Bob: 9544 photons arrived, 7621 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7621
#   Sifted bits:            3808
#   QBER:                   0.0316
#   Secure key rate:        0.2041
#   Final key bits:         2041
#   Elapsed:                50.25s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7621
#   sifted_bits: 3808
#   qber: 0.031578947368421054
#   secure_key_rate: 0.2041
#   final_key_bits: 2041
#   elapsed_seconds: 50.245572090148926
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.9, latency_ms=100 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3820
#   QBER:            0.0576
#   Secure key rate: 0.1252
#   Final key bits:  1252
#   Elapsed:         84.15s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9584 photons
# Bob: 9584 photons arrived, 7672 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7672
#   Sifted bits:            3820
#   QBER:                   0.0576
#   Secure key rate:        0.1252
#   Final key bits:         1252
#   Elapsed:                94.05s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7672
#   sifted_bits: 3820
#   qber: 0.05759162303664921
#   secure_key_rate: 0.1252
#   final_key_bits: 1252
#   elapsed_seconds: 94.04779171943665
#
# ##### polarization_fidelity=0.9, latency_ms=100 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3823
#   QBER:            0.0497
#   Secure key rate: 0.1477
#   Final key bits:  1477
#   Elapsed:         82.99s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9575 photons
# Bob: 9575 photons arrived, 7622 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7622
#   Sifted bits:            3823
#   QBER:                   0.0497
#   Secure key rate:        0.1477
#   Final key bits:         1477
#   Elapsed:                92.89s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7622
#   sifted_bits: 3823
#   qber: 0.049738219895287955
#   secure_key_rate: 0.1477
#   final_key_bits: 1477
#   elapsed_seconds: 92.8877305984497
#
# ##### polarization_fidelity=0.9, latency_ms=100 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3819
#   QBER:            0.0394
#   Secure key rate: 0.1791
#   Final key bits:  1791
#   Elapsed:         76.94s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9519 photons
# Bob: 9519 photons arrived, 7589 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7589
#   Sifted bits:            3819
#   QBER:                   0.0394
#   Secure key rate:        0.1791
#   Final key bits:         1791
#   Elapsed:                86.84s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7589
#   sifted_bits: 3819
#   qber: 0.03937007874015748
#   secure_key_rate: 0.1791
#   final_key_bits: 1791
#   elapsed_seconds: 86.8396692276001
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 200ms
#   bob (enp7s0): netem delay 200ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=0.9, latency_ms=200 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3942
#   QBER:            0.0736
#   Secure key rate: 0.0856
#   Final key bits:  856
#   Elapsed:         123.00s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9570 photons
# Bob: 9570 photons arrived, 7731 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7731
#   Sifted bits:            3942
#   QBER:                   0.0736
#   Secure key rate:        0.0856
#   Final key bits:         856
#   Elapsed:                132.79s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7731
#   sifted_bits: 3942
#   qber: 0.07360406091370558
#   secure_key_rate: 0.0856
#   final_key_bits: 856
#   elapsed_seconds: 132.78595757484436
#
# ##### polarization_fidelity=0.9, latency_ms=200 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3768
#   QBER:            0.0559
#   Secure key rate: 0.1283
#   Final key bits:  1283
#   Elapsed:         123.05s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9514 photons
# Bob: 9514 photons arrived, 7598 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7598
#   Sifted bits:            3768
#   QBER:                   0.0559
#   Secure key rate:        0.1283
#   Final key bits:         1283
#   Elapsed:                132.85s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7598
#   sifted_bits: 3768
#   qber: 0.05585106382978723
#   secure_key_rate: 0.1283
#   final_key_bits: 1283
#   elapsed_seconds: 132.84657263755798
#
# ##### polarization_fidelity=0.9, latency_ms=200 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3773
#   QBER:            0.0398
#   Secure key rate: 0.1756
#   Final key bits:  1756
#   Elapsed:         122.28s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9603 photons
# Bob: 9603 photons arrived, 7668 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7668
#   Sifted bits:            3773
#   QBER:                   0.0398
#   Secure key rate:        0.1756
#   Final key bits:         1756
#   Elapsed:                132.09s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
# ...
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=1.0, latency_ms=100 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3821
#   QBER:            0.0000
#   Secure key rate: 0.3439
#   Final key bits:  3439
#   Elapsed:         84.28s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9554 photons
# Bob: 9554 photons arrived, 7633 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7633
#   Sifted bits:            3821
#   QBER:                   0.0000
#   Secure key rate:        0.3439
#   Final key bits:         3439
#   Elapsed:                94.18s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7633
#   sifted_bits: 3821
#   qber: 0.0
#   secure_key_rate: 0.3439
#   final_key_bits: 3439
#   elapsed_seconds: 94.17854523658752
#
# ##### polarization_fidelity=1.0, latency_ms=100 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3838
#   QBER:            0.0000
#   Secure key rate: 0.3455
#   Final key bits:  3455
#   Elapsed:         81.05s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9570 photons
# Bob: 9570 photons arrived, 7672 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7672
#   Sifted bits:            3838
#   QBER:                   0.0000
#   Secure key rate:        0.3455
#   Final key bits:         3455
#   Elapsed:                90.95s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7672
#   sifted_bits: 3838
#   qber: 0.0
#   secure_key_rate: 0.3455
#   final_key_bits: 3455
#   elapsed_seconds: 90.94735455513
#
# ##### polarization_fidelity=1.0, latency_ms=100 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3766
#   QBER:            0.0000
#   Secure key rate: 0.3390
#   Final key bits:  3390
#   Elapsed:         84.11s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9538 photons
# Bob: 9538 photons arrived, 7594 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7594
#   Sifted bits:            3766
#   QBER:                   0.0000
#   Secure key rate:        0.3390
#   Final key bits:         3390
#   Elapsed:                94.00s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7594
#   sifted_bits: 3766
#   qber: 0.0
#   secure_key_rate: 0.339
#   final_key_bits: 3390
#   elapsed_seconds: 94.00428128242493
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 200ms
#   bob (enp7s0): netem delay 200ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### polarization_fidelity=1.0, latency_ms=200 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3820
#   QBER:            0.0000
#   Secure key rate: 0.3438
#   Final key bits:  3438
#   Elapsed:         121.46s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9571 photons
# Bob: 9571 photons arrived, 7666 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7666
#   Sifted bits:            3820
#   QBER:                   0.0000
#   Secure key rate:        0.3438
#   Final key bits:         3438
#   Elapsed:                131.26s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7666
#   sifted_bits: 3820
#   qber: 0.0
#   secure_key_rate: 0.3438
#   final_key_bits: 3438
#   elapsed_seconds: 131.2579915523529
#
# ##### polarization_fidelity=1.0, latency_ms=200 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3753
#   QBER:            0.0000
#   Secure key rate: 0.3378
#   Final key bits:  3378
#   Elapsed:         118.93s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9526 photons
# Bob: 9526 photons arrived, 7645 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7645
#   Sifted bits:            3753
#   QBER:                   0.0000
#   Secure key rate:        0.3378
#   Final key bits:         3378
#   Elapsed:                128.74s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7645
#   sifted_bits: 3753
#   qber: 0.0
#   secure_key_rate: 0.3378
#   final_key_bits: 3378
#   elapsed_seconds: 128.7362961769104
#
# ##### polarization_fidelity=1.0, latency_ms=200 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3795
#   QBER:            0.0000
#   Secure key rate: 0.3416
#   Final key bits:  3416
#   Elapsed:         123.87s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9558 photons
# Bob: 9558 photons arrived, 7650 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7650
#   Sifted bits:            3795
#   QBER:                   0.0000
#   Secure key rate:        0.3416
#   Final key bits:         3416
#   Elapsed:                133.67s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7650
#   sifted_bits: 3795
#   qber: 0.0
#   secure_key_rate: 0.3416
#   final_key_bits: 3416
#   elapsed_seconds: 133.6715750694275
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# Saved -> /home/fabric/work/qkd-pqc-dependability/results/joint_polarization_fidelity_x_latency_ms.json (27 rows total)

# %%
import shutil, time
results_dir = PROJECT_DIR / "results"
shutil.copy(results_dir / "joint_polarization_fidelity_x_latency_ms.json", results_dir / f"joint_pf_x_latency_BACKUP_{int(time.time())}.json")
# Out:
# PosixPath('/home/fabric/work/qkd-pqc-dependability/results/joint_pf_x_latency_BACKUP_1785344251.json')

# %%
joint_results['loss_x_efficiency'] = deploy.run_joint_axis_sweep(slice_obj, 'loss_pct', 'efficiency', loss_vals, eff_vals)
# Out:
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 1%
#   bob (enp7s0): netem loss 1%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### loss_pct=1, efficiency=0.5 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2396
#   QBER:            0.0167
#   Secure key rate: 0.1627
#   Final key bits:  1627
#   Elapsed:         37.63s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9569 photons
# Bob: 9569 photons arrived, 4739 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4739
#   Sifted bits:            2396
#   QBER:                   0.0167
#   Secure key rate:        0.1627
#   Final key bits:         1627
#   Elapsed:                47.63s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4739
#   sifted_bits: 2396
#   qber: 0.016736401673640166
#   secure_key_rate: 0.1627
#   final_key_bits: 1627
#   elapsed_seconds: 47.634385108947754
#
# ##### loss_pct=1, efficiency=0.5 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2347
#   QBER:            0.0128
#   Secure key rate: 0.1694
#   Final key bits:  1694
#   Elapsed:         38.80s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9570 photons
# Bob: 9570 photons arrived, 4677 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4677
#   Sifted bits:            2347
#   QBER:                   0.0128
#   Secure key rate:        0.1694
#   Final key bits:         1694
#   Elapsed:                48.80s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4677
#   sifted_bits: 2347
#   qber: 0.01282051282051282
#   secure_key_rate: 0.1694
#   final_key_bits: 1694
#   elapsed_seconds: 48.80125284194946
#
# ##### loss_pct=1, efficiency=0.5 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2414
#   QBER:            0.0041
#   Secure key rate: 0.2004
#   Final key bits:  2004
#   Elapsed:         39.65s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9549 photons
# Bob: 9549 photons arrived, 4767 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4767
#   Sifted bits:            2414
#   QBER:                   0.0041
#   Secure key rate:        0.2004
#   Final key bits:         2004
#   Elapsed:                49.65s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4767
#   sifted_bits: 2414
#   qber: 0.004149377593360996
#   secure_key_rate: 0.2004
#   final_key_bits: 2004
#   elapsed_seconds: 49.65236210823059
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 1%
#   bob (enp7s0): netem loss 1%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### loss_pct=1, efficiency=0.8 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3822
#   QBER:            0.0079
#   Secure key rate: 0.2984
#   Final key bits:  2984
#   Elapsed:         39.37s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9573 photons
# Bob: 9573 photons arrived, 7674 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7674
#   Sifted bits:            3822
#   QBER:                   0.0079
#   Secure key rate:        0.2984
#   Final key bits:         2984
#   Elapsed:                49.37s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7674
#   sifted_bits: 3822
#   qber: 0.007853403141361256
#   secure_key_rate: 0.2984
#   final_key_bits: 2984
#   elapsed_seconds: 49.37281560897827
#
# ##### loss_pct=1, efficiency=0.8 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3746
#   QBER:            0.0107
#   Secure key rate: 0.2796
#   Final key bits:  2796
#   Elapsed:         37.79s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9566 photons
# Bob: 9566 photons arrived, 7669 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7669
#   Sifted bits:            3746
#   QBER:                   0.0107
#   Secure key rate:        0.2796
#   Final key bits:         2796
#   Elapsed:                47.79s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7669
#   sifted_bits: 3746
#   qber: 0.0106951871657754
#   secure_key_rate: 0.2796
#   final_key_bits: 2796
#   elapsed_seconds: 47.7876079082489
#
# ##### loss_pct=1, efficiency=0.8 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3930
#   QBER:            0.0025
#   Secure key rate: 0.3355
#   Final key bits:  3355
#   Elapsed:         38.79s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9540 photons
# Bob: 9540 photons arrived, 7682 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7682
#   Sifted bits:            3930
#   QBER:                   0.0025
#   Secure key rate:        0.3355
#   Final key bits:         3355
#   Elapsed:                48.79s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7682
#   sifted_bits: 3930
#   qber: 0.002544529262086514
#   secure_key_rate: 0.3355
#   final_key_bits: 3355
#   elapsed_seconds: 48.788679361343384
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 1%
#   bob (enp7s0): netem loss 1%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### loss_pct=1, efficiency=1.0 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4773
#   QBER:            0.0084
#   Secure key rate: 0.3695
#   Final key bits:  3695
#   Elapsed:         41.58s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9561 photons
# Bob: 9561 photons arrived, 9561 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9561
#   Sifted bits:            4773
#   QBER:                   0.0084
#   Secure key rate:        0.3695
#   Final key bits:         3695
#   Elapsed:                51.60s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9561
#   sifted_bits: 4773
#   qber: 0.008385744234800839
#   secure_key_rate: 0.3695
#   final_key_bits: 3695
#   elapsed_seconds: 51.59718918800354
#
# ##### loss_pct=1, efficiency=1.0 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4782
#   QBER:            0.0146
#   Secure key rate: 0.3355
#   Final key bits:  3355
#   Elapsed:         38.21s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9566 photons
# Bob: 9566 photons arrived, 9566 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9566
#   Sifted bits:            4782
#   QBER:                   0.0146
#   Secure key rate:        0.3355
#   Final key bits:         3355
#   Elapsed:                48.20s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9566
#   sifted_bits: 4782
#   qber: 0.014644351464435146
#   secure_key_rate: 0.3355
#   final_key_bits: 3355
#   elapsed_seconds: 48.204862117767334
#
# ##### loss_pct=1, efficiency=1.0 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4844
#   QBER:            0.0083
#   Secure key rate: 0.3757
#   Final key bits:  3757
#   Elapsed:         40.43s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9560 photons
# Bob: 9560 photons arrived, 9560 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9560
#   Sifted bits:            4844
#   QBER:                   0.0083
#   Secure key rate:        0.3757
#   Final key bits:         3757
#   Elapsed:                50.43s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9560
#   sifted_bits: 4844
#   qber: 0.008264462809917356
#   secure_key_rate: 0.3757
#   final_key_bits: 3757
#   elapsed_seconds: 50.42677044868469
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 10%
#   bob (enp7s0): netem loss 10%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### loss_pct=10, efficiency=0.5 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2403
#   QBER:            0.0083
#   Secure key rate: 0.1862
#   Final key bits:  1862
#   Elapsed:         45.07s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9553 photons
# Bob: 9553 photons arrived, 4743 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4743
#   Sifted bits:            2403
#   QBER:                   0.0083
#   Secure key rate:        0.1862
#   Final key bits:         1862
#   Elapsed:                55.07s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4743
#   sifted_bits: 2403
#   qber: 0.008333333333333333
#   secure_key_rate: 0.1862
#   final_key_bits: 1862
#   elapsed_seconds: 55.07228755950928
#
# ##### loss_pct=10, efficiency=0.5 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2328
#   QBER:            0.0086
#   Secure key rate: 0.1796
#   Final key bits:  1796
#   Elapsed:         100.74s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9592 photons
# Bob: 9592 photons arrived, 4761 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4761
#   Sifted bits:            2328
#   QBER:                   0.0086
#   Secure key rate:        0.1796
#   Final key bits:         1796
#   Elapsed:                110.74s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4761
#   sifted_bits: 2328
#   qber: 0.008620689655172414
#   secure_key_rate: 0.1796
#   final_key_bits: 1796
#   elapsed_seconds: 110.74088096618652
#
# ##### loss_pct=10, efficiency=0.5 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2296
#   QBER:            0.0175
#   Secure key rate: 0.1542
#   Final key bits:  1542
#   Elapsed:         60.83s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9589 photons
# Bob: 9589 photons arrived, 4701 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4701
#   Sifted bits:            2296
#   QBER:                   0.0175
#   Secure key rate:        0.1542
#   Final key bits:         1542
#   Elapsed:                70.83s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4701
#   sifted_bits: 2296
#   qber: 0.017467248908296942
#   secure_key_rate: 0.1542
#   final_key_bits: 1542
#   elapsed_seconds: 70.83102893829346
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 10%
#   bob (enp7s0): netem loss 10%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### loss_pct=10, efficiency=0.8 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3901
#   QBER:            0.0179
#   Secure key rate: 0.2599
#   Final key bits:  2599
#   Elapsed:         50.07s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9560 photons
# Bob: 9560 photons arrived, 7667 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7667
#   Sifted bits:            3901
#   QBER:                   0.0179
#   Secure key rate:        0.2599
#   Final key bits:         2599
#   Elapsed:                60.08s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7667
#   sifted_bits: 3901
#   qber: 0.017948717948717947
#   secure_key_rate: 0.2599
#   final_key_bits: 2599
#   elapsed_seconds: 60.07721138000488
#
# ##### loss_pct=10, efficiency=0.8 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3885
#   QBER:            0.0077
#   Secure key rate: 0.3039
#   Final key bits:  3039
#   Elapsed:         47.88s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9515 photons
# Bob: 9515 photons arrived, 7641 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7641
#   Sifted bits:            3885
#   QBER:                   0.0077
#   Secure key rate:        0.3039
#   Final key bits:         3039
#   Elapsed:                57.88s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7641
#   sifted_bits: 3885
#   qber: 0.007731958762886598
#   secure_key_rate: 0.3039
#   final_key_bits: 3039
#   elapsed_seconds: 57.87902641296387
#
# ##### loss_pct=10, efficiency=0.8 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3840
#   QBER:            0.0182
#   Secure key rate: 0.2547
#   Final key bits:  2547
#   Elapsed:         51.60s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9526 photons
# Bob: 9526 photons arrived, 7633 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7633
#   Sifted bits:            3840
#   QBER:                   0.0182
#   Secure key rate:        0.2547
#   Final key bits:         2547
#   Elapsed:                61.57s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7633
#   sifted_bits: 3840
#   qber: 0.018229166666666668
#   secure_key_rate: 0.2547
#   final_key_bits: 2547
#   elapsed_seconds: 61.57365322113037
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 10%
#   bob (enp7s0): netem loss 10%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### loss_pct=10, efficiency=1.0 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4723
#   QBER:            0.0085
#   Secure key rate: 0.3651
#   Final key bits:  3651
#   Elapsed:         46.09s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9552 photons
# Bob: 9552 photons arrived, 9552 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9552
#   Sifted bits:            4723
#   QBER:                   0.0085
#   Secure key rate:        0.3651
#   Final key bits:         3651
#   Elapsed:                56.08s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9552
#   sifted_bits: 4723
#   qber: 0.00847457627118644
#   secure_key_rate: 0.3651
#   final_key_bits: 3651
#   elapsed_seconds: 56.08479571342468
#
# ##### loss_pct=10, efficiency=1.0 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4646
#   QBER:            0.0129
#   Secure key rate: 0.3348
#   Final key bits:  3348
#   Elapsed:         56.43s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9531 photons
# Bob: 9531 photons arrived, 9531 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9531
#   Sifted bits:            4646
#   QBER:                   0.0129
#   Secure key rate:        0.3348
#   Final key bits:         3348
#   Elapsed:                66.43s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9531
#   sifted_bits: 4646
#   qber: 0.01293103448275862
#   secure_key_rate: 0.3348
#   final_key_bits: 3348
#   elapsed_seconds: 66.42965483665466
#
# ##### loss_pct=10, efficiency=1.0 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4744
#   QBER:            0.0211
#   Secure key rate: 0.3009
#   Final key bits:  3009
#   Elapsed:         48.50s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9582 photons
# Bob: 9582 photons arrived, 9582 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9582
#   Sifted bits:            4744
#   QBER:                   0.0211
#   Secure key rate:        0.3009
#   Final key bits:         3009
#   Elapsed:                58.47s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9582
#   sifted_bits: 4744
#   qber: 0.02109704641350211
#   secure_key_rate: 0.3009
#   final_key_bits: 3009
#   elapsed_seconds: 58.470638036727905
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 15%
#   bob (enp7s0): netem loss 15%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### loss_pct=15, efficiency=0.5 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/ubuntu/qfabric/qne/cli.py", line 154, in <module>
#     main()
#   File "/home/ubuntu/qfabric/qne/cli.py", line 148, in main
#     _run_alice(args)
#   File "/home/ubuntu/qfabric/qne/cli.py", line 121, in _run_alice
#     metrics = alice.run()
#   File "/home/ubuntu/qfabric/qne/alice.py", line 87, in run
#     self._run_sifting()
#   File "/home/ubuntu/qfabric/qne/alice.py", line 158, in _run_sifting
#     msg = channel.recv_message()
#   File "/home/ubuntu/qfabric/qne/channel.py", line 51, in recv_message
#     header = self._recv_exact(4)
#   File "/home/ubuntu/qfabric/qne/channel.py", line 60, in _recv_exact
#     chunk = self._sock.recv(n - len(buf))
# TimeoutError: timed out
# Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#
#   cleared classical netem on Alice and Bob
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 joint_results['loss_x_efficiency'] = deploy.run_joint_axis_sweep(slice_obj, 'loss_pct', 'efficiency', loss_vals, eff_vals)
#
# File ~/work/qkd-pqc-dependability/scripts/deploy_fabric_modified.py:1548, in run_joint_axis_sweep(slice_obj, axis1, axis2, values1, values2, scenario_path, n_runs, port, save_json, resume)
#    1546     continue
#    1547 print(f"\n##### {axis1}={v1}, {axis2}={v2} (run {run_idx}/{n_runs}) #####")
# -> 1548 row = _run_one(run_path, {axis1: v1, axis2: v2}, run_idx)
#    1549 rows.append(row)
#    1550 if not row.get("error"):
#
# File ~/work/qkd-pqc-dependability/scripts/deploy_fabric_modified.py:1477, in run_joint_axis_sweep.<locals>._run_one(scenario_path_for_run, row_meta, run_idx, timeout_s)
#    1475 run_start = _time.time()
#    1476 try:
# -> 1477     run_bb84(slice_obj, scenario_path_for_run, alice_mac, bob_mac,
#    1478              sw_alice_mac=sw_alice_mac, bob_data_ip="10.10.1.2")
#    1479 except Exception as e:
#    1480     print(f"  !! run failed under {row_meta}: {e}")
#
# File ~/work/qkd-pqc-dependability/scripts/deploy_fabric_modified.py:725, in run_bb84(slice_obj, scenario_path, alice_mac, bob_mac, sw_alice_mac, bob_data_ip)
#     723 time.sleep(5)
#     724 try:
# --> 725     bob_result = bob_thread.result()
#     726     print("  Bob finished")
#     727     print(f"  Bob output: {str(bob_result[0])[:500]}")
#
# File /opt/conda/lib/python3.13/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File /opt/conda/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     357 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     358     if timeout is None:
# --> 359         waiter.acquire()
#     360         gotit = True
#     361     else:
#
# KeyboardInterrupt:

# %%
joint_results['loss_x_efficiency'] = deploy.run_joint_axis_sweep(slice_obj, 'loss_pct', 'efficiency', loss_vals, eff_vals)
# Out:
# Resuming: 18 rows loaded, 18 successful runs will be skipped
# skip (already done): loss_pct=1, efficiency=0.5
# skip (already done): loss_pct=1, efficiency=0.8
# skip (already done): loss_pct=1, efficiency=1.0
# skip (already done): loss_pct=10, efficiency=0.5
# skip (already done): loss_pct=10, efficiency=0.8
# skip (already done): loss_pct=10, efficiency=1.0
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 15%
#   bob (enp7s0): netem loss 15%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### loss_pct=15, efficiency=0.5 (run 1/3) #####
# pkill: killing pid 111507 failed: Operation not permitted
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
# LISTEN 0      1            0.0.0.0:5100      0.0.0.0:*
#     !! port 5100 still held on bob after 15s
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2342
#   QBER:            0.0085
#   Secure key rate: 0.1808
#   Final key bits:  1808
#   Elapsed:         70.23s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9568 photons
# Bob: 9568 photons arrived, 4728 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4728
#   Sifted bits:            2342
#   QBER:                   0.0085
#   Secure key rate:        0.1808
#   Final key bits:         1808
#   Elapsed:                80.23s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4728
#   sifted_bits: 2342
#   qber: 0.008547008547008548
#   secure_key_rate: 0.1808
#   final_key_bits: 1808
#   elapsed_seconds: 80.23381614685059
#
# ##### loss_pct=15, efficiency=0.5 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2374
#   QBER:            0.0000
#   Secure key rate: 0.2137
#   Final key bits:  2137
#   Elapsed:         50.59s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9555 photons
# Bob: 9555 photons arrived, 4707 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4707
#   Sifted bits:            2374
#   QBER:                   0.0000
#   Secure key rate:        0.2137
#   Final key bits:         2137
#   Elapsed:                60.59s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4707
#   sifted_bits: 2374
#   qber: 0.0
#   secure_key_rate: 0.2137
#   final_key_bits: 2137
#   elapsed_seconds: 60.59137749671936
#
# ##### loss_pct=15, efficiency=0.5 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2385
#   QBER:            0.0126
#   Secure key rate: 0.1727
#   Final key bits:  1727
#   Elapsed:         40.89s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9580 photons
# Bob: 9580 photons arrived, 4764 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4764
#   Sifted bits:            2385
#   QBER:                   0.0126
#   Secure key rate:        0.1727
#   Final key bits:         1727
#   Elapsed:                50.87s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4764
#   sifted_bits: 2385
#   qber: 0.012605042016806723
#   secure_key_rate: 0.1727
#   final_key_bits: 1727
#   elapsed_seconds: 50.87297773361206
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 15%
#   bob (enp7s0): netem loss 15%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### loss_pct=15, efficiency=0.8 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3820
#   QBER:            0.0079
#   Secure key rate: 0.2982
#   Final key bits:  2982
#   Elapsed:         130.90s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9557 photons
# Bob: 9557 photons arrived, 7672 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7672
#   Sifted bits:            3820
#   QBER:                   0.0079
#   Secure key rate:        0.2982
#   Final key bits:         2982
#   Elapsed:                140.91s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7672
#   sifted_bits: 3820
#   qber: 0.007853403141361256
#   secure_key_rate: 0.2982
#   final_key_bits: 2982
#   elapsed_seconds: 140.91171550750732
#
# ##### loss_pct=15, efficiency=0.8 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3830
#   QBER:            0.0131
#   Secure key rate: 0.2754
#   Final key bits:  2754
#   Elapsed:         127.09s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9543 photons
# Bob: 9543 photons arrived, 7650 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7650
#   Sifted bits:            3830
#   QBER:                   0.0131
#   Secure key rate:        0.2754
#   Final key bits:         2754
#   Elapsed:                137.09s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7650
#   sifted_bits: 3830
#   qber: 0.013054830287206266
#   secure_key_rate: 0.2754
#   final_key_bits: 2754
#   elapsed_seconds: 137.0865888595581
#
# ##### loss_pct=15, efficiency=0.8 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3838
#   QBER:            0.0104
#   Secure key rate: 0.2876
#   Final key bits:  2876
#   Elapsed:         77.22s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9535 photons
# Bob: 9535 photons arrived, 7622 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7622
#   Sifted bits:            3838
#   QBER:                   0.0104
#   Secure key rate:        0.2876
#   Final key bits:         2876
#   Elapsed:                87.22s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7622
#   sifted_bits: 3838
#   qber: 0.010443864229765013
#   secure_key_rate: 0.2876
#   final_key_bits: 2876
#   elapsed_seconds: 87.21567726135254
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem loss 15%
#   bob (enp7s0): netem loss 15%
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### loss_pct=15, efficiency=1.0 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4741
#   QBER:            0.0148
#   Secure key rate: 0.3320
#   Final key bits:  3320
#   Elapsed:         66.24s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9547 photons
# Bob: 9547 photons arrived, 9547 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9547
#   Sifted bits:            4741
#   QBER:                   0.0148
#   Secure key rate:        0.3320
#   Final key bits:         3320
#   Elapsed:                76.15s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9547
#   sifted_bits: 4741
#   qber: 0.014767932489451477
#   secure_key_rate: 0.332
#   final_key_bits: 3320
#   elapsed_seconds: 76.14593362808228
#
# ##### loss_pct=15, efficiency=1.0 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4743
#   QBER:            0.0169
#   Secure key rate: 0.3214
#   Final key bits:  3214
#   Elapsed:         51.39s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9527 photons
# Bob: 9527 photons arrived, 9527 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9527
#   Sifted bits:            4743
#   QBER:                   0.0169
#   Secure key rate:        0.3214
#   Final key bits:         3214
#   Elapsed:                61.37s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9527
#   sifted_bits: 4743
#   qber: 0.016877637130801686
#   secure_key_rate: 0.3214
#   final_key_bits: 3214
#   elapsed_seconds: 61.36774134635925
#
# ##### loss_pct=15, efficiency=1.0 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4763
#   QBER:            0.0084
#   Secure key rate: 0.3686
#   Final key bits:  3686
#   Elapsed:         46.53s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9541 photons
# Bob: 9541 photons arrived, 9541 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9541
#   Sifted bits:            4763
#   QBER:                   0.0084
#   Secure key rate:        0.3686
#   Final key bits:         3686
#   Elapsed:                56.53s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9541
#   sifted_bits: 4763
#   qber: 0.008403361344537815
#   secure_key_rate: 0.3686
#   final_key_bits: 3686
#   elapsed_seconds: 56.531657457351685
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# Saved -> /home/fabric/work/qkd-pqc-dependability/results/joint_loss_pct_x_efficiency.json (27 rows total)

# %%
shutil.copy(results_dir / "joint_loss_pct_x_efficiency.json", results_dir / f"joint_loss_x_efficiency_BACKUP_{int(time.time())}.json")
# Out:
# PosixPath('/home/fabric/work/qkd-pqc-dependability/results/joint_loss_x_efficiency_BACKUP_1785347938.json')

# %%
joint_results['latency_x_efficiency'] = deploy.run_joint_axis_sweep(slice_obj, 'latency_ms', 'efficiency', latency_vals, eff_vals)
# Out:
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 1ms
#   bob (enp7s0): netem delay 1ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### latency_ms=1, efficiency=0.5 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2346
#   QBER:            0.0000
#   Secure key rate: 0.2112
#   Final key bits:  2112
#   Elapsed:         38.81s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9542 photons
# Bob: 9542 photons arrived, 4737 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4737
#   Sifted bits:            2346
#   QBER:                   0.0000
#   Secure key rate:        0.2112
#   Final key bits:         2112
#   Elapsed:                48.81s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4737
#   sifted_bits: 2346
#   qber: 0.0
#   secure_key_rate: 0.2112
#   final_key_bits: 2112
#   elapsed_seconds: 48.81261587142944
#
# ##### latency_ms=1, efficiency=0.5 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2440
#   QBER:            0.0123
#   Secure key rate: 0.1775
#   Final key bits:  1775
#   Elapsed:         39.16s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9574 photons
# Bob: 9574 photons arrived, 4789 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4789
#   Sifted bits:            2440
#   QBER:                   0.0123
#   Secure key rate:        0.1775
#   Final key bits:         1775
#   Elapsed:                49.16s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4789
#   sifted_bits: 2440
#   qber: 0.012295081967213115
#   secure_key_rate: 0.1775
#   final_key_bits: 1775
#   elapsed_seconds: 49.16038656234741
#
# ##### latency_ms=1, efficiency=0.5 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2362
#   QBER:            0.0127
#   Secure key rate: 0.1708
#   Final key bits:  1708
#   Elapsed:         37.48s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9575 photons
# Bob: 9575 photons arrived, 4698 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4698
#   Sifted bits:            2362
#   QBER:                   0.0127
#   Secure key rate:        0.1708
#   Final key bits:         1708
#   Elapsed:                47.47s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4698
#   sifted_bits: 2362
#   qber: 0.012711864406779662
#   secure_key_rate: 0.1708
#   final_key_bits: 1708
#   elapsed_seconds: 47.4726996421814
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 1ms
#   bob (enp7s0): netem delay 1ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### latency_ms=1, efficiency=0.8 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3867
#   QBER:            0.0026
#   Secure key rate: 0.3300
#   Final key bits:  3300
#   Elapsed:         39.41s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9563 photons
# Bob: 9563 photons arrived, 7634 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7634
#   Sifted bits:            3867
#   QBER:                   0.0026
#   Secure key rate:        0.3300
#   Final key bits:         3300
#   Elapsed:                49.41s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7634
#   sifted_bits: 3867
#   qber: 0.0025906735751295338
#   secure_key_rate: 0.33
#   final_key_bits: 3300
#   elapsed_seconds: 49.40809416770935
#
# ##### latency_ms=1, efficiency=0.8 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3897
#   QBER:            0.0103
#   Secure key rate: 0.2928
#   Final key bits:  2928
#   Elapsed:         39.83s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9549 photons
# Bob: 9549 photons arrived, 7644 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7644
#   Sifted bits:            3897
#   QBER:                   0.0103
#   Secure key rate:        0.2928
#   Final key bits:         2928
#   Elapsed:                49.85s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7644
#   sifted_bits: 3897
#   qber: 0.010282776349614395
#   secure_key_rate: 0.2928
#   final_key_bits: 2928
#   elapsed_seconds: 49.84561896324158
#
# ##### latency_ms=1, efficiency=0.8 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3855
#   QBER:            0.0026
#   Secure key rate: 0.3289
#   Final key bits:  3289
#   Elapsed:         40.23s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9549 photons
# Bob: 9549 photons arrived, 7637 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7637
#   Sifted bits:            3855
#   QBER:                   0.0026
#   Secure key rate:        0.3289
#   Final key bits:         3289
#   Elapsed:                50.23s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7637
#   sifted_bits: 3855
#   qber: 0.0025974025974025974
#   secure_key_rate: 0.3289
#   final_key_bits: 3289
#   elapsed_seconds: 50.229594469070435
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 1ms
#   bob (enp7s0): netem delay 1ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### latency_ms=1, efficiency=1.0 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4744
#   QBER:            0.0169
#   Secure key rate: 0.3215
#   Final key bits:  3215
#   Elapsed:         39.92s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9583 photons
# Bob: 9583 photons arrived, 9583 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9583
#   Sifted bits:            4744
#   QBER:                   0.0169
#   Secure key rate:        0.3215
#   Final key bits:         3215
#   Elapsed:                49.92s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9583
#   sifted_bits: 4744
#   qber: 0.016877637130801686
#   secure_key_rate: 0.3215
#   final_key_bits: 3215
#   elapsed_seconds: 49.922301292419434
#
# ##### latency_ms=1, efficiency=1.0 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4769
#   QBER:            0.0105
#   Secure key rate: 0.3570
#   Final key bits:  3570
#   Elapsed:         38.68s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9532 photons
# Bob: 9532 photons arrived, 9532 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9532
#   Sifted bits:            4769
#   QBER:                   0.0105
#   Secure key rate:        0.3570
#   Final key bits:         3570
#   Elapsed:                48.68s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9532
#   sifted_bits: 4769
#   qber: 0.01050420168067227
#   secure_key_rate: 0.357
#   final_key_bits: 3570
#   elapsed_seconds: 48.67981481552124
#
# ##### latency_ms=1, efficiency=1.0 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 16/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4753
#   QBER:            0.0084
#   Secure key rate: 0.3677
#   Final key bits:  3677
#   Elapsed:         40.07s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9584 photons
# Bob: 9584 photons arrived, 9584 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9584
#   Sifted bits:            4753
#   QBER:                   0.0084
#   Secure key rate:        0.3677
#   Final key bits:         3677
#   Elapsed:                50.07s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9584
#   sifted_bits: 4753
#   qber: 0.008421052631578947
#   secure_key_rate: 0.3677
#   final_key_bits: 3677
#   elapsed_seconds: 50.06974768638611
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### latency_ms=100, efficiency=0.5 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2331
#   QBER:            0.0129
#   Secure key rate: 0.1681
#   Final key bits:  1681
#   Elapsed:         75.66s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9541 photons
# Bob: 9541 photons arrived, 4745 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4745
#   Sifted bits:            2331
#   QBER:                   0.0129
#   Secure key rate:        0.1681
#   Final key bits:         1681
#   Elapsed:                85.56s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4745
#   sifted_bits: 2331
#   qber: 0.012875536480686695
#   secure_key_rate: 0.1681
#   final_key_bits: 1681
#   elapsed_seconds: 85.55976986885071
#
# ##### latency_ms=100, efficiency=0.5 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2358
#   QBER:            0.0170
#   Secure key rate: 0.1594
#   Final key bits:  1594
#   Elapsed:         75.79s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9587 photons
# Bob: 9587 photons arrived, 4698 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4698
#   Sifted bits:            2358
#   QBER:                   0.0170
#   Secure key rate:        0.1594
#   Final key bits:         1594
#   Elapsed:                85.69s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4698
#   sifted_bits: 2358
#   qber: 0.01702127659574468
#   secure_key_rate: 0.1594
#   final_key_bits: 1594
#   elapsed_seconds: 85.69145798683167
#
# ##### latency_ms=100, efficiency=0.5 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     2373
#   QBER:            0.0084
#   Secure key rate: 0.1835
#   Final key bits:  1835
#   Elapsed:         74.59s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9546 photons
# Bob: 9546 photons arrived, 4709 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 4709
#   Sifted bits:            2373
#   QBER:                   0.0084
#   Secure key rate:        0.1835
#   Final key bits:         1835
#   Elapsed:                84.48s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4709
#   sifted_bits: 2373
#   qber: 0.008438818565400843
#   secure_key_rate: 0.1835
#   final_key_bits: 1835
#   elapsed_seconds: 84.48218846321106
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### latency_ms=100, efficiency=0.8 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3936
#   QBER:            0.0076
#   Secure key rate: 0.3084
#   Final key bits:  3084
#   Elapsed:         84.16s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9523 photons
# Bob: 9523 photons arrived, 7646 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7646
#   Sifted bits:            3936
#   QBER:                   0.0076
#   Secure key rate:        0.3084
#   Final key bits:         3084
#   Elapsed:                94.06s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7646
#   sifted_bits: 3936
#   qber: 0.007633587786259542
#   secure_key_rate: 0.3084
#   final_key_bits: 3084
#   elapsed_seconds: 94.0590615272522
#
# ##### latency_ms=100, efficiency=0.8 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3787
#   QBER:            0.0106
#   Secure key rate: 0.2832
#   Final key bits:  2832
#   Elapsed:         77.40s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9551 photons
# Bob: 9551 photons arrived, 7688 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7688
#   Sifted bits:            3787
#   QBER:                   0.0106
#   Secure key rate:        0.2832
#   Final key bits:         2832
#   Elapsed:                87.32s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7688
#   sifted_bits: 3787
#   qber: 0.010582010582010581
#   secure_key_rate: 0.2832
#   final_key_bits: 2832
#   elapsed_seconds: 87.32037782669067
#
# ##### latency_ms=100, efficiency=0.8 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3817
#   QBER:            0.0026
#   Secure key rate: 0.3255
#   Final key bits:  3255
#   Elapsed:         83.09s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9549 photons
# Bob: 9549 photons arrived, 7646 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7646
#   Sifted bits:            3817
#   QBER:                   0.0026
#   Secure key rate:        0.3255
#   Final key bits:         3255
#   Elapsed:                92.99s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7646
#   sifted_bits: 3817
#   qber: 0.0026246719160104987
#   secure_key_rate: 0.3255
#   final_key_bits: 3255
#   elapsed_seconds: 92.99059128761292
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 100ms
#   bob (enp7s0): netem delay 100ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### latency_ms=100, efficiency=1.0 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4805
#   QBER:            0.0063
#   Secure key rate: 0.3851
#   Final key bits:  3851
#   Elapsed:         87.41s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9581 photons
# Bob: 9581 photons arrived, 9581 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9581
#   Sifted bits:            4805
#   QBER:                   0.0063
#   Secure key rate:        0.3851
#   Final key bits:         3851
#   Elapsed:                97.31s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9581
#   sifted_bits: 4805
#   qber: 0.00625
#   secure_key_rate: 0.3851
#   final_key_bits: 3851
#   elapsed_seconds: 97.31167459487915
#
# ##### latency_ms=100, efficiency=1.0 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4736
#   QBER:            0.0063
#   Secure key rate: 0.3790
#   Final key bits:  3790
#   Elapsed:         84.29s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9531 photons
# Bob: 9531 photons arrived, 9531 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9531
#   Sifted bits:            4736
#   QBER:                   0.0063
#   Secure key rate:        0.3790
#   Final key bits:         3790
#   Elapsed:                94.18s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9531
#   sifted_bits: 4736
#   qber: 0.006342494714587738
#   secure_key_rate: 0.379
#   final_key_bits: 3790
#   elapsed_seconds: 94.18412232398987
#
# ##### latency_ms=100, efficiency=1.0 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 14/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 15/60)...
#
# === Alice Results ===
#   Photons sent:    10000
# ...
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 4766
#   sifted_bits: 2383
#   qber: 0.01680672268907563
#   secure_key_rate: 0.1616
#   final_key_bits: 1616
#   elapsed_seconds: 120.29539585113525
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 200ms
#   bob (enp7s0): netem delay 200ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### latency_ms=200, efficiency=0.8 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3804
#   QBER:            0.0132
#   Secure key rate: 0.2731
#   Final key bits:  2731
#   Elapsed:         112.11s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9573 photons
# Bob: 9573 photons arrived, 7671 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7671
#   Sifted bits:            3804
#   QBER:                   0.0132
#   Secure key rate:        0.2731
#   Final key bits:         2731
#   Elapsed:                121.90s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7671
#   sifted_bits: 3804
#   qber: 0.013157894736842105
#   secure_key_rate: 0.2731
#   final_key_bits: 2731
#   elapsed_seconds: 121.8958306312561
#
# ##### latency_ms=200, efficiency=0.8 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3835
#   QBER:            0.0131
#   Secure key rate: 0.2758
#   Final key bits:  2758
#   Elapsed:         111.54s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9576 photons
# Bob: 9576 photons arrived, 7656 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7656
#   Sifted bits:            3835
#   QBER:                   0.0131
#   Secure key rate:        0.2758
#   Final key bits:         2758
#   Elapsed:                121.34s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7656
#   sifted_bits: 3835
#   qber: 0.013054830287206266
#   secure_key_rate: 0.2758
#   final_key_bits: 2758
#   elapsed_seconds: 121.34173631668091
#
# ##### latency_ms=200, efficiency=0.8 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     3781
#   QBER:            0.0132
#   Secure key rate: 0.2712
#   Final key bits:  2712
#   Elapsed:         111.70s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9562 photons
# Bob: 9562 photons arrived, 7647 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 7647
#   Sifted bits:            3781
#   QBER:                   0.0132
#   Secure key rate:        0.2712
#   Final key bits:         2712
#   Elapsed:                121.50s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 7647
#   sifted_bits: 3781
#   qber: 0.013227513227513227
#   secure_key_rate: 0.2712
#   final_key_bits: 2712
#   elapsed_seconds: 121.50276255607605
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# === Applying classical-channel netem (TCP:5100) ===
#   alice (enp7s0): netem delay 200ms
#   bob (enp7s0): netem delay 200ms
#
# === Configuring switch (threshold=193305371) ===
#   Switch interfaces: enp8s0 (Alice), enp7s0 (Bob)
#   Alice MAC: 0E:A9:B5:58:70:AB
#   Bob MAC:   02:49:B1:09:C5:4F
#   Switch Alice-side MAC: 1A:9E:9B:43:74:D7
#   Switch Bob-side MAC:   16:E2:21:CF:C2:97
#   Compiling P4 program...
#   Starting BMv2...
#   Configuring tables...
#   Switch configured and running
#
# ##### latency_ms=200, efficiency=1.0 (run 1/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4741
#   QBER:            0.0063
#   Secure key rate: 0.3794
#   Final key bits:  3794
#   Elapsed:         133.85s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9508 photons
# Bob: 9508 photons arrived, 9508 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9508
#   Sifted bits:            4741
#   QBER:                   0.0063
#   Secure key rate:        0.3794
#   Final key bits:         3794
#   Elapsed:                143.67s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9508
#   sifted_bits: 4741
#   qber: 0.006329113924050633
#   secure_key_rate: 0.3794
#   final_key_bits: 3794
#   elapsed_seconds: 143.66635632514954
#
# ##### latency_ms=200, efficiency=1.0 (run 2/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4808
#   QBER:            0.0146
#   Secure key rate: 0.3377
#   Final key bits:  3377
#   Elapsed:         128.98s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9486 photons
# Bob: 9486 photons arrived, 9486 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9486
#   Sifted bits:            4808
#   QBER:                   0.0146
#   Secure key rate:        0.3377
#   Final key bits:         3377
#   Elapsed:                138.78s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9486
#   sifted_bits: 4808
#   qber: 0.014583333333333334
#   secure_key_rate: 0.3377
#   final_key_bits: 3377
#   elapsed_seconds: 138.77754759788513
#
# ##### latency_ms=200, efficiency=1.0 (run 3/3) #####
#
# === Running BB84 protocol ===
#   Bob data-plane IP: 10.10.1.2 (for classical channel)
#   Alice data iface:  enp7s0
#   Bob data iface:    enp7s0
#   Cleaning up previous runs...
#   Ensuring deps on alice...
#   Ensuring deps on bob...
#   Starting Bob...
#   Alice MAC args:  --dst-mac '1A:9E:9B:43:74:D7' --src-mac '0E:A9:B5:58:70:AB'
#   Starting Alice...
#   Waiting for BB84 to complete...
#   Alice finished
#   Alice output: Alice: Sending 10000 photons on enp7s0
# Alice: Finished sending 10000 photons
# Alice: Connecting to Bob at 10.10.1.2:5100
#   Retrying connection to 10.10.1.2:5100 (attempt 2/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 3/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 4/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 5/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 6/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 7/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 8/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 9/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 10/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 11/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 12/60)...
#   Retrying connection to 10.10.1.2:5100 (attempt 13/60)...
#
# === Alice Results ===
#   Photons sent:    10000
#   Sifted bits:     4768
#   QBER:            0.0189
#   Secure key rate: 0.3130
#   Final key bits:  3130
#   Elapsed:         130.00s
# Metrics saved to results/alice_results.json
#
#   Bob finished
#   Bob output: Bob: Listening for photons on enp7s0
# Bob: Timeout — received 9532 photons
# Bob: 9532 photons arrived, 9532 detected
# Bob: Waiting for Alice on 0.0.0.0:5100
# Bob: Alice connected
#
# === Bob Results ===
#   Photons received (raw): 9532
#   Sifted bits:            4768
#   QBER:                   0.0189
#   Secure key rate:        0.3130
#   Final key bits:         3130
#   Elapsed:                139.80s
# Metrics saved to results/bob_results.json
#
#
# === Collecting results ===
#   Saved bob results to /home/fabric/work/qkd-pqc-dependability/results/fabric_bob_results.json
#   Saved alice results to /home/fabric/work/qkd-pqc-dependability/results/fabric_alice_results.json
#
# === FABRIC BB84 Results ===
#   photons_sent: 10000
#   photons_received: 9532
#   sifted_bits: 4768
#   qber: 0.018907563025210083
#   secure_key_rate: 0.313
#   final_key_bits: 3130
#   elapsed_seconds: 139.79954504966736
#   cleared classical netem on Alice and Bob
#   cleared classical netem on Alice and Bob
#
# Saved -> /home/fabric/work/qkd-pqc-dependability/results/joint_latency_ms_x_efficiency.json (27 rows total)

# %%
def plot_joint_pair(joint_rows, axis1, axis2, save_path=None, ci=0.95):
    """Line graphs for one joint-sweep pair: mean key rate, mean QBER, and
    success probability, each with (axis1-level, axis2-value) confidence
    intervals from repeated runs. One line per axis1 level, x-axis = axis2.
    """
    import pandas as pd
    import matplotlib.pyplot as plt
    from scipy import stats
    import numpy as np

    df = pd.DataFrame(joint_rows)

    if 'success' not in df.columns:
        has_error = df['error'].notna() if 'error' in df.columns else False
        df['success'] = (df['qber'] < 0.11) & (df['key_bits_per_sec'] >= 1.0) & (~has_error)

    summary = df.groupby([axis1, axis2]).agg(
        key_rate_mean=('key_bits_per_sec', 'mean'),
        key_rate_std=('key_bits_per_sec', 'std'),
        qber_mean=('qber', 'mean'),
        qber_std=('qber', 'std'),
        success_prob=('success', 'mean'),
        success_std=('success', 'std'),
        n=('success', 'size'),
    ).reset_index()

    def _ci_halfwidth(std, n):
        if n <= 1 or pd.isna(std):
            return 0.0
        t_crit = stats.t.ppf(0.5 + ci / 2, n - 1)
        return t_crit * std / np.sqrt(n)

    summary['key_rate_ci'] = summary.apply(lambda r: _ci_halfwidth(r['key_rate_std'], r['n']), axis=1)
    summary['qber_ci'] = summary.apply(lambda r: _ci_halfwidth(r['qber_std'], r['n']), axis=1)
    summary['success_ci'] = summary.apply(lambda r: _ci_halfwidth(r['success_std'], r['n']), axis=1)

    fig, axs = plt.subplots(1, 3, figsize=(18, 5))
    axis1_levels = sorted(summary[axis1].unique())

    for ax, y_col, ci_col, title, ylabel in [
        (axs[0], 'key_rate_mean', 'key_rate_ci', 'Key Rate', 'key bits/sec'),
        (axs[1], 'qber_mean', 'qber_ci', 'QBER', 'QBER'),
        (axs[2], 'success_prob', 'success_ci', 'Success Probability', 'P(success)'),
    ]:
        for level in axis1_levels:
            d = summary[summary[axis1] == level].sort_values(axis2)
            ax.errorbar(d[axis2], d[y_col], yerr=d[ci_col], marker='o', capsize=3,
                        label=f"{axis1}={level}")
        ax.set_title(f"{axis1} x {axis2}\n{title} ({int(ci*100)}% CI)")
        ax.set_xlabel(axis2)
        ax.set_ylabel(ylabel)
        if title == 'QBER':
            ax.axhline(0.11, color='red', linestyle='--', linewidth=1, label='11% threshold')
        ax.legend(fontsize=8)

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=150)
    plt.show()


def two_way_anova(raw_df, axis1, axis2, y_col='qber'):
    """Two-way ANOVA testing main effects of axis1, axis2, and their
    interaction on y_col. Uses statsmodels; requires raw per-run data
    (one row per run, not pre-aggregated).
    """
    import pandas as pd
    import statsmodels.api as sm
    from statsmodels.formula.api import ols

    df = raw_df.copy()
    # column names with special chars (e.g. dark_count_rate_hz is fine, but
    # be safe and rename to generic a/b for the formula)
    df = df.rename(columns={axis1: 'a', axis2: 'b', y_col: 'y'})
    df = df.dropna(subset=['a', 'b', 'y'])

    model = ols('y ~ C(a) * C(b)', data=df).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)

    return {
        "axis1": axis1, "axis2": axis2, "y_col": y_col,
        "anova_table": anova_table,
        "model": model,
    }

# %%
plot_joint_pair(joint_results['pf_x_loss'], 'polarization_fidelity', 'loss_pct',
                 save_path='/home/fabric/work/qkd-pqc-dependability/results/polarization_fidelity_x_loss_pct_plot.png')

import pandas as pd
df_pf_loss = pd.DataFrame(joint_results['pf_x_loss'])
result = two_way_anova(df_pf_loss, 'polarization_fidelity', 'loss_pct', y_col='qber')
print(result['anova_table'])
# Out:
# /tmp/ipykernel_82/1057834559.py:15: DeprecationWarning: Bitwise inversion '~' on bool is deprecated and will be removed in Python 3.16. This returns the bitwise inversion of the underlying int object and is usually not what you expect from negating a bool. Use the 'not' operator for boolean negation or ~int(x) if you really want the bitwise inversion of the underlying int.
#   df['success'] = (df['qber'] < 0.11) & (df['key_bits_per_sec'] >= 1.0) & (~has_error)
#              sum_sq    df           F        PR(>F)
# C(a)       0.038383   2.0  278.251259  2.909545e-14
# C(b)       0.000476   2.0    3.451132  5.386454e-02
# C(a):C(b)  0.001996   4.0    7.234973  1.174178e-03
# Residual   0.001241  18.0         NaN           NaN

# %%
def joint_ols_regression(joint_rows, axis1, axis2, y_col='key_bits_per_sec'):
    """OLS regression with interaction term, treating both axes as continuous
    predictors (not categorical, unlike two_way_anova's C(a)*C(b)). Use this
    when you want a fitted slope/interaction coefficient rather than a
    factor-level ANOVA table — e.g. to report an actual interaction effect
    size for the paper.

    joint_rows: list of row dicts as returned by run_joint_axis_sweep.
    """
    import pandas as pd
    import statsmodels.formula.api as smf

    df = pd.DataFrame(joint_rows)
    df = df.rename(columns={axis1: 'x1', axis2: 'x2', y_col: 'y'})
    df = df.dropna(subset=['x1', 'x2', 'y'])

    model = smf.ols("y ~ x1 * x2", data=df).fit()
    print(f"=== {axis1} x {axis2} -> {y_col} ===")
    print(model.summary())
    return model

# %%
model_pf_eff = joint_ols_regression(joint_results['pf_x_efficiency'], 'polarization_fidelity', 'efficiency', y_col='key_bits_per_sec')
model_pf_loss = joint_ols_regression(joint_results['pf_x_loss'], 'polarization_fidelity', 'loss_pct', y_col='key_bits_per_sec')
model_pf_latency = joint_ols_regression(joint_results['pf_x_latency'], 'polarization_fidelity', 'latency_ms', y_col='key_bits_per_sec')
